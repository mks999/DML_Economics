# %% [markdown]
# <a href="https://colab.research.google.com/github/mks999/DML_Economics/blob/main/DML_PLR_and_Feature_Inference_2_9_25_Hi_Semi_Lo_EMP_EQI_IMF_PanelMultiDiD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1.Package Installation and Setup

# Install required packages
# !pip install doubleml scikit-learn pandas numpy openpyxl matplotlib seaborn

# Import libraries
import pandas as pd
import numpy as np
from doubleml import DoubleMLData, DoubleMLPLR, DoubleMLIRM
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

print("=== COMPREHENSIVE DML ANALYSIS: EXPORT QUALITY & EMPLOYMENT ===")
print("Integrated PLR-IRM Framework for Multiple Specifications")
print("Comparable with GMM and Driscoll-Kraay Results")
print("=" * 70)
# Out:
# Requirement already satisfied: doubleml in /usr/local/lib/python3.12/dist-packages (0.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from doubleml) (1.5.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from doubleml) (1.16.1)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.12/dist-packages (from doubleml) (0.14.5)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from doubleml) (5.24.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->doubleml) (8.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels->doubleml) (1.0.1)
# === COMPREHENSIVE DML ANALYSIS: EXPORT QUALITY & EMPLOYMENT ===
# Integrated PLR-IRM Framework for Multiple Specifications
# Comparable with GMM and Driscoll-Kraay Results
# ======================================================================

# %%
#2: Data Loading and Preparation

# Load data
file_path = '/content/imputed Hi Lo Semi EQ_IMF 31.8.25.xlsx'
df = pd.read_excel(file_path)

print("Data Overview:")
print(f"Shape: {df.shape}")
print(f"Countries: {df['country'].nunique()}")
print(f"Time period: {df['time'].min()}-{df['time'].max()}")
print("\nAvailable columns:")
print(df.columns.tolist())

# Basic data cleaning
df = df.sort_values(['ctryid', 'time']).reset_index(drop=True)

print(f"\nData after sorting: {df.shape}")
print("\nSample data:")
print(df.head(35))
# Out:
# Data Overview:
# Shape: (660, 25)
# Countries: 33
# Time period: 1995-2014
#
# Available columns:
# ['country', 'time', 'mhtx', 'rnd', 'tariff', 'mobile', 'uv_index', 'gfcf', 'fdi', 'lnwages', 'reer', 'd1', 'aggemp', 'ctryid', 'dmy_uvindex', 'dmy_mhtx', 'msch', 'internet', 'covid_dummy', 'L_aggemp', 'High Skill', 'Low Skill', 'EQI_IMF', 'dmy_EQIimf', 'Semi Skill']
#
# Data after sorting: (660, 25)
#
# Sample data:
#     country  time     mhtx      rnd  tariff     mobile  uv_index     gfcf  \
# 0   Austria  1995  54.3446  1.53577  10.810    4.82598     75.77  27.1040
# 1   Austria  1996  55.8184  1.58077   6.941    7.52331     62.18  26.4922
# 2   Austria  1997  55.8653  1.65491   5.372   14.55610     60.50  26.3834
# 3   Austria  1998  55.4894  1.73155   3.199   28.74800     61.43  26.2500
# 4   Austria  1999  56.2713  1.84537   2.697   53.18720     76.14  26.2733
# 5   Austria  2000  58.8933  1.88602   2.410   76.36300     67.60  25.9401
# 6   Austria  2001  58.7735  1.99210   3.370   81.35950     66.30  25.4261
# 7   Austria  2002  59.3115  2.06598   2.450   83.37670     69.50  23.7780
# 8   Austria  2003  59.0448  2.17456   2.520   89.58010     82.00  24.4562
# 9   Austria  2004  61.3670  2.16612   2.240   97.80670     91.20  24.2037
# 10  Austria  2005  60.0458  2.37324   2.460  105.32400     94.30  23.9653
# 11  Austria  2006  60.7318  2.35923   2.300  112.25500     98.70  23.8293
# 12  Austria  2007  59.9629  2.41843   2.240  119.49800    111.20  24.7335
# 13  Austria  2008  59.2642  2.56945   1.720  129.98200    122.90  24.7048
# 14  Austria  2009  59.5030  2.59674   1.850  137.05000    113.60  23.0148
# 15  Austria  2010  59.9732  2.72610   2.130  146.37400    110.40  22.8593
# 16  Austria  2011  59.9296  2.66868   1.590  155.19300    121.10  24.3522
# 17  Austria  2012  61.0583  2.91472   1.460  161.19300    114.00  24.2559
# 18  Austria  2013  62.0474  2.95492   1.490  156.51800    117.80  23.9413
# 19  Austria  2014  61.9364  3.08429   2.030  151.56200    117.50  23.8487
# 20  Belgium  1995  52.5238  1.64729  12.910    2.33040     57.22  21.7908
# 21  Belgium  1996  53.1884  1.74299  10.808    4.72351     56.23  21.6307
# 22  Belgium  1997  52.9027  1.80971   9.998    9.59632     55.83  22.3003
# 23  Belgium  1998  53.7402  1.83825   6.781   17.23790     56.32  22.3487
# 24  Belgium  1999  53.9736  1.90565   5.796   31.16720     53.29  22.6890
# 25  Belgium  2000  53.7316  1.93620   2.410   54.84030     65.90  23.7830
# 26  Belgium  2001  55.9727  2.03279   3.370   74.66110     64.90  22.6338
# 27  Belgium  2002  56.8608  1.90325   2.450   78.23590     67.70  20.7474
# 28  Belgium  2003  57.2573  1.84119   2.520   82.72810     80.30  20.9647
# 29  Belgium  2004  56.5322  1.82050   2.240   87.33320     89.70  22.6671
# 30  Belgium  2005  55.9808  1.79061   2.460   91.32560     94.50  23.6811
# 31  Belgium  2006  55.4081  1.82269   2.300   93.04920     99.20  23.9705
# 32  Belgium  2007  55.1793  1.84999   2.240  100.79200    111.10  24.6033
# 33  Belgium  2008  54.6651  1.93684   1.720  105.73300    123.80  25.9368
# 34  Belgium  2009  56.2926  1.99860   1.850  109.01600    109.70  22.0264
#
#           fdi  lnwages  ...  dmy_mhtx     msch   internet  covid_dummy  \
# 0    0.760156  23.0443  ...   54.3446  10.6529   1.400470            0
# 1    1.832370  23.0658  ...   55.8184  10.7436   0.820036            0
# 2    1.260590  23.0707  ...   55.8653  10.8343   0.316014            0
# 3    2.106190  23.1061  ...   55.4894  10.9250   0.599989            0
# 4    1.374400  23.1523  ...   56.2713  11.0157   0.636937            0
# 5    4.333240  23.1848  ...   58.8933  11.1064   2.377410            0
# 6    2.895720  23.1759  ...   58.7735  11.1971   3.986460            0
# 7    0.065001  23.2058  ...   59.3115  11.2879   5.580550            0
# 8    2.375580  23.2491  ...   59.0448  11.3786   7.399110            0
# 9    1.064020  23.3028  ...   61.3670  11.4693  10.644200            0
# 10  25.830700  23.4000  ...   60.0458  11.5600  14.266300            0
# 11   3.144730  23.4700  ...   60.7318  11.5450  17.315800            0
# 12  17.805800  23.4857  ...   59.9629  11.5300  19.549300            0
# 13   1.468000  23.5460  ...   59.2642  11.4700  20.773100            0
# 14   3.581370  23.5953  ...   59.5030  11.6700  22.510600            0
# 15  -5.645400  23.6105  ...   59.9732  11.7100  24.511400            0
# 16   5.358130  23.6313  ...   59.9296  11.7100  24.992600            0
# 17   1.283000  23.6832  ...   61.0583  11.7500  25.264500            0
# 18  -0.302633  23.7112  ...   62.0474  11.7900  26.322300            0
# 19   0.389557  23.7306  ...   61.9364  12.0100  27.597700            0
# 20   3.711020  22.7064  ...   52.5238  10.1075   0.892304            0
# 21   5.037190  22.7022  ...   53.1884  10.1943   1.347640            0
# 22   4.747890  22.7263  ...   52.9027  10.2811   1.083600            0
# 23   8.776790  22.7416  ...   53.7402  10.3679   0.107219            0
# 24  46.348500  22.7886  ...   53.9736  10.4547   0.224956            0
# 25  37.475300  22.8436  ...   53.7316  10.5415   1.406740            0
# 26  37.256500  22.8914  ...   55.9727  10.6387   4.471770            0
# 27   7.012420  22.9353  ...   56.8608  10.7358   7.891420            0
# 28  10.864900  22.9582  ...   57.2573  10.8330  11.978600            0
# 29  12.052100  22.9389  ...   56.5322  10.9301  15.544600            0
# 30   8.727180  22.9871  ...   55.9808  11.0273  19.187000            0
# 31  14.407900  23.0410  ...   55.4081  11.0500  23.241200            0
# 32  20.502700  23.0685  ...   55.1793  11.1150  25.689400            0
# 33  36.802900  23.1372  ...   54.6651  11.1800  27.848600            0
# 34  15.948900  23.1820  ...   56.2926  11.3200  29.161900            0
#
#     L_aggemp  High Skill  Low Skill   EQI_IMF  dmy_EQIimf  Semi Skill
# 0     56.975        80.6       40.0  1.013102    1.013102        66.0
# 1     56.843        77.1       37.6  1.012188    1.012188        65.3
# 2     55.711        77.5       36.2  1.008185    1.008185        64.7
# 3     55.402        79.5       34.8  1.009592    1.009592        65.4
# 4     55.592        74.7       35.5  1.005306    1.005306        65.5
# 5     56.195        76.1       34.6  1.004338    1.004338        65.0
# 6     55.934        76.5       34.0  1.000403    1.000403        64.5
# 7     55.904        75.4       34.9  1.002478    1.002478        63.5
# 8     56.071        75.0       34.1  1.001994    1.001994        64.5
# 9     56.323        72.2       31.4  1.001801    1.001801        62.5
# 10    54.576        73.6       32.2  1.002722    1.002722        62.5
# 11    55.135        74.3       32.9  1.006260    1.006260        62.6
# 12    55.834        75.1       34.8  1.010809    1.010809        63.5
# 13    56.893        74.0       34.5  1.007032    1.007032        64.4
# 14    57.558        73.9       33.5  1.017480    1.017480        63.5
# 15    57.107        73.6       33.4  1.013740    1.013740        63.7
# 16    57.343        74.1       33.8  1.016401    1.016401        63.6
# 17    57.558        74.8       33.1  1.025939    1.025939        63.6
# 18    57.670        74.4       32.4  1.027911    1.027911        63.4
# 19    57.538        73.6       32.7  1.015609    1.015609        60.8
# 20    45.476        76.9       28.8  0.926753    0.926501        57.8
# 21    45.813        76.3       27.6  0.924016    0.924448        57.2
# 22    45.626        76.7       27.2  0.924016    0.924448        57.9
# 23    45.999        77.2       28.1  0.891988    0.894104        57.6
# 24    46.112        78.7       29.2  0.897108    0.896509        58.8
# 25    47.421        79.4       30.4  1.011359    1.011359        59.4
# 26    48.849        77.4       28.3  0.999162    0.999162        59.7
# 27    47.747        76.2       28.4  1.003585    1.003585        58.8
# 28    47.651        76.0       27.9  1.004957    1.004957        58.7
# 29    47.404        77.2       27.7  1.006645    1.006645        57.9
# 30    48.199        76.0       27.1  1.008198    1.008198        58.7
# 31    48.801        75.0       28.8  1.011376    1.011376        58.1
# 32    48.735        76.2       29.0  1.007796    1.007796        58.3
# 33    49.589        75.4       28.4  1.009401    1.009401        59.4
# 34    49.934        74.2       27.3  1.018152    1.018152        57.6
#
# [35 rows x 25 columns]

# %%
# 3: Model Specifications Setup

# Define comprehensive model specifications
MODEL_SPECS = {
    'spec_1_gmm_nodummy': {
        'name': 'GMM Spec 1 (No Dummies)',
        'controls': ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'reer'],
        'dummies': [],
        'description': 'Comparable to GMM Spec 1 without dummies'
    },
    'spec_1_gmm_ctrydummy': {
        'name': 'GMM Spec 1 (Country Dummies)',
        'controls': ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'reer'],
        'dummies': ['dmy_treatment'],
        'description': 'Comparable to GMM Spec 1 with country dummies'
    },
    'spec_2_gmm_nodummy': {
        'name': 'GMM Spec 2 (No Dummies)',
        'controls': ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'lnwages', 'reer'],
        'dummies': [],
        'description': 'Comparable to GMM Spec 2 without dummies'
    },
    'spec_2_gmm_ctrydummy': {
        'name': 'GMM Spec 2 (Country Dummies)',
        'controls': ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'lnwages', 'reer'],
        'dummies': ['dmy_treatment'],
        'description': 'Comparable to GMM Spec 2 with country dummies'
    },
     'spec_3_gmm_nodummy': {
        'name': 'GMM Spec 3 (No Dummies)',
        'controls': ['fdi', 'gfcf', 'rnd', 'tariff', 'msch'],
        'dummies': [],
        'description': 'Comparable to GMM Spec 3 without dummies'
    },
    'spec_3_gmm_ctrydummy': {
        'name': 'GMM Spec 3 (Country Dummies)',
        'controls': ['fdi', 'gfcf', 'rnd', 'tariff', 'msch'],
        'dummies': ['dmy_treatment'],
        'description': 'Comparable to GMM Spec 3 with country dummies'
    },
      'spec_4_gmm_nodummy': {
        'name': 'GMM Spec 4 (No Dummies)',
        'controls': ['fdi', 'gfcf', 'rnd', 'tariff', 'internet'],
        'dummies': [],
        'description': 'Comparable to GMM Spec 4 without dummies'
    },
    'spec_4_gmm_ctrydummy': {
        'name': 'GMM Spec 4 (Country Dummies)',
        'controls': ['fdi', 'gfcf', 'rnd', 'tariff', 'internet'],
        'dummies': ['dmy_treatment'],
        'description': 'Comparable to GMM Spec 4 with country dummies'
    },
      'spec_5_gmm_nodummy': {
        'name': 'GMM Spec 5 (No Dummies)',
        'controls': ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch'],
        'dummies': [],
        'description': 'Comparable to GMM Spec 5 with dummies'
    },
    'spec_5_gmm_ctrydummy': {
        'name': 'GMM Spec 5 (Country Dummies)',
        'controls': ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch'],
        'dummies': ['dmy_treatment'],
        'description': 'Comparable to GMM Spec 5 with country dummies'
    },
      'spec_6_gmm_nodummy': {
        'name': 'GMM Spec 6 (No Dummies)',
        'controls': ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer'],
        'dummies': [],
        'description': 'Comparable to GMM Spec 6 without dummies'
    },
    'spec_6_gmm_ctrydummy': {
        'name': 'GMM Spec 6 (Country Dummies)',
        'controls': ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer'],
        'dummies': ['dmy_treatment'],
        'description': 'Comparable to GMM Spec 6 with country dummies'
    },
     'spec_7_gmm_nodummy': {
        'name': 'GMM Spec 7 (No Dummies)',
        'controls': ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer'],
        'dummies': [],
        'description': 'Comparable to GMM Spec 7 without dummies'
    },
    'spec_7_gmm_ctrydummy': {
        'name': 'GMM Spec 7 (Country Dummies)',
        'controls': ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer'],
        'dummies': ['dmy_treatment'],
        'description': 'Comparable to GMM Spec 7 with country dummies'
    }
}


# Define analysis framework
DEPENDENT_VARS = {
    'High Skill': 'High Skill Employment',
    'Low Skill': 'Low Skill Employment',
    'Semi Skill': 'Semi Skill Employment'
}

TREATMENT_VARS = {
    'EQI_IMF': 'Export Quality Indicator (IMF)'
}

print("MODEL SPECIFICATIONS:")
print("=" * 50)
for spec_id, spec in MODEL_SPECS.items():
    print(f"{spec_id}: {spec['name']}")
    print(f"  Description: {spec['description']}")
    print(f"  Controls: {len(spec['controls'])} variables")
    print(f"  Dummies: {spec['dummies']}")
    print()

print("ANALYSIS FRAMEWORK:")
print(f"Dependent Variables: {list(DEPENDENT_VARS.keys())}")
print(f"Treatment Variables: {list(TREATMENT_VARS.keys())}")
print(f"Total Combinations: {len(DEPENDENT_VARS) * len(TREATMENT_VARS) * len(MODEL_SPECS)}")
# Out:
# MODEL SPECIFICATIONS:
# ==================================================
# spec_1_gmm_nodummy: GMM Spec 1 (No Dummies)
#   Description: Comparable to GMM Spec 1 without dummies
#   Controls: 7 variables
#   Dummies: []
#
# spec_1_gmm_ctrydummy: GMM Spec 1 (Country Dummies)
#   Description: Comparable to GMM Spec 1 with country dummies
#   Controls: 7 variables
#   Dummies: ['dmy_treatment']
#
# spec_2_gmm_nodummy: GMM Spec 2 (No Dummies)
#   Description: Comparable to GMM Spec 2 without dummies
#   Controls: 8 variables
#   Dummies: []
#
# spec_2_gmm_ctrydummy: GMM Spec 2 (Country Dummies)
#   Description: Comparable to GMM Spec 2 with country dummies
#   Controls: 8 variables
#   Dummies: ['dmy_treatment']
#
# spec_3_gmm_nodummy: GMM Spec 3 (No Dummies)
#   Description: Comparable to GMM Spec 3 without dummies
#   Controls: 5 variables
#   Dummies: []
#
# spec_3_gmm_ctrydummy: GMM Spec 3 (Country Dummies)
#   Description: Comparable to GMM Spec 3 with country dummies
#   Controls: 5 variables
#   Dummies: ['dmy_treatment']
#
# spec_4_gmm_nodummy: GMM Spec 4 (No Dummies)
#   Description: Comparable to GMM Spec 4 without dummies
#   Controls: 5 variables
#   Dummies: []
#
# spec_4_gmm_ctrydummy: GMM Spec 4 (Country Dummies)
#   Description: Comparable to GMM Spec 4 with country dummies
#   Controls: 5 variables
#   Dummies: ['dmy_treatment']
#
# spec_5_gmm_nodummy: GMM Spec 5 (No Dummies)
#   Description: Comparable to GMM Spec 5 with dummies
#   Controls: 6 variables
#   Dummies: []
#
# spec_5_gmm_ctrydummy: GMM Spec 5 (Country Dummies)
#   Description: Comparable to GMM Spec 5 with country dummies
#   Controls: 6 variables
#   Dummies: ['dmy_treatment']
#
# spec_6_gmm_nodummy: GMM Spec 6 (No Dummies)
#   Description: Comparable to GMM Spec 6 without dummies
#   Controls: 7 variables
#   Dummies: []
#
# spec_6_gmm_ctrydummy: GMM Spec 6 (Country Dummies)
#   Description: Comparable to GMM Spec 6 with country dummies
#   Controls: 7 variables
#   Dummies: ['dmy_treatment']
#
# spec_7_gmm_nodummy: GMM Spec 7 (No Dummies)
#   Description: Comparable to GMM Spec 7 without dummies
#   Controls: 7 variables
#   Dummies: []
#
# spec_7_gmm_ctrydummy: GMM Spec 7 (Country Dummies)
#   Description: Comparable to GMM Spec 7 with country dummies
#   Controls: 7 variables
#   Dummies: ['dmy_treatment']
#
# ANALYSIS FRAMEWORK:
# Dependent Variables: ['High Skill', 'Low Skill', 'Semi Skill']
# Treatment Variables: ['EQI_IMF']
# Total Combinations: 42

# %%
# 4: Analysis Functions

def prepare_data_for_analysis(df, y_col, treatment_col, spec_name):
    """
    Prepare data for DML analysis based on specification
    """
    spec = MODEL_SPECS[spec_name]

    # Start with base controls
    x_cols = spec['controls'].copy()

    # Add dummies if specified
    if spec['dummies']:
        for dummy in spec['dummies']:
            if dummy == 'dmy_treatment':
                # Dynamically set treatment dummy - only include EQI_IMF
                if treatment_col == 'EQI_IMF':
                    x_cols.append('dmy_EQIimf')
                # Removed conditions for 'mhtx' and 'uv_index'
            else:
                x_cols.append(dummy)

    # Select required columns
    required_cols = [y_col, treatment_col] + x_cols

    # Check available columns
    available_cols = [col for col in required_cols if col in df.columns]
    missing_cols = [col for col in required_cols if col not in df.columns]

    if missing_cols:
        print(f"Warning: Missing columns {missing_cols}")
        print(f"Available columns: {available_cols}")

    # Use available columns
    df_clean = df[available_cols].copy() # Create a copy to avoid SettingWithCopyWarning

    # --- Data Cleaning: Convert relevant columns to numeric, handling errors ---
    cols_to_convert = [y_col, treatment_col] + [col for col in x_cols if col in df_clean.columns]
    for col in cols_to_convert:
        # Replace the problematic character '`' and convert to numeric
        if df_clean[col].dtype == 'object': # Only attempt replace on object type columns
            df_clean[col] = df_clean[col].astype(str).str.replace('`', '', regex=False)
        df_clean[col] = pd.to_numeric(df_clean[col], errors='coerce')
    # --- End Data Cleaning ---


    df_clean.dropna(inplace=True) # Drop rows with NaN values after conversion

    actual_x_cols = [col for col in x_cols if col in df_clean.columns and col != treatment_col] # Ensure treatment is not in x_cols

    return df_clean, actual_x_cols, len(df) - len(df_clean)

def run_plr_analysis(df_clean, y_col, treatment_col, x_cols, spec_name):
    """
    Run PLR analysis
    """
    # Create DoubleML data object
    dml_data = DoubleMLData(df_clean, y_col=y_col, d_cols=treatment_col, x_cols=x_cols)

    # Define ML models
    ml_l = GradientBoostingRegressor(n_estimators=200, max_depth=4, random_state=42)
    ml_m = RandomForestRegressor(n_estimators=200, max_depth=4, random_state=42)

    # Fit PLR model
    dml_plr = DoubleMLPLR(dml_data, ml_l=ml_l, ml_m=ml_m, n_folds=5, n_rep=3)
    dml_plr.fit(store_models=True)

    return dml_plr

print("Analysis functions defined successfully!")
print("Functions available:")
print("- prepare_data_for_analysis(): Data preparation for each specification")
print("- run_plr_analysis(): PLR model estimation")
# Out:
# Analysis functions defined successfully!
# Functions available:
# - prepare_data_for_analysis(): Data preparation for each specification
# - run_plr_analysis(): PLR model estimation

# %%
#5: Main Analysis Loop - PLR Results

# Initialize results storage
plr_results = {}
data_info = {}

print("=" * 70)
print("PLR ANALYSIS RESULTS")
print("=" * 70)

# Run analysis for each combination
for dep_var, dep_desc in DEPENDENT_VARS.items():
    if dep_var not in df.columns:
        print(f"Skipping {dep_var} - not available in dataset")
        continue

    for treat_var, treat_desc in TREATMENT_VARS.items():
        for spec_id, spec in MODEL_SPECS.items(): # Iterate through all new specifications

            print(f"\n{'='*50}")
            print(f"ANALYSIS: {dep_desc} ~ {treat_desc}")
            print(f"SPECIFICATION: {spec['name']}")
            print(f"{'='*50}")

            try:
                # Prepare data
                df_clean, x_cols, missing_obs = prepare_data_for_analysis(
                    df, dep_var, treat_var, spec_id
                )

                print(f"Data prepared: {len(df_clean)} obs, {missing_obs} dropped")
                print(f"Controls used: {x_cols}")

                # Run PLR
                dml_plr = run_plr_analysis(df_clean, dep_var, treat_var, x_cols, spec_id)

                # Store results
                key = f"{dep_var}_{treat_var}_{spec_id}"
                plr_results[key] = {
                    'model': dml_plr,
                    'coef': dml_plr.coef[0], # Access the scalar value
                    'se': dml_plr.se[0],     # Access the scalar value
                    'pval': dml_plr.pval[0],   # Access the scalar value
                    'ci_lower': dml_plr.coef[0] - 1.96 * dml_plr.se[0], # Access scalar values
                    'ci_upper': dml_plr.coef[0] + 1.96 * dml_plr.se[0], # Access scalar values
                    'n_obs': len(df_clean),
                    'dep_var': dep_var,
                    'treat_var': treat_var,
                    'spec_id': spec_id,
                    'controls': x_cols
                }

                data_info[key] = {
                    'df_clean': df_clean,
                    'x_cols': x_cols
                }

                # Display results - format the scalar values
                print(f"\nPLR RESULTS:")
                print(f"Coefficient: {plr_results[key]['coef']:.4f}")
                print(f"Std Error: {plr_results[key]['se']:.4f}")
                print(f"P-value: {plr_results[key]['pval']:.4f}")
                print(f"95% CI: [{plr_results[key]['ci_lower']:.4f}, {plr_results[key]['ci_upper']:.4f}]")

                significance = "***" if plr_results[key]['pval'] < 0.01 else "**" if plr_results[key]['pval'] < 0.05 else "*" if plr_results[key]['pval'] < 0.1 else ""
                print(f"Significance: {significance}")

            except Exception as e:
                print(f"Error in analysis: {str(e)}")
                continue

print(f"\n\nPLR ANALYSIS COMPLETED!")
print(f"Total successful analyses: {len(plr_results)}")
# Out:
# ======================================================================
# PLR ANALYSIS RESULTS
# ======================================================================
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 1 (No Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'reer']
#
# PLR RESULTS:
# Coefficient: -2.3059
# Std Error: 4.6761
# P-value: 0.6219
# 95% CI: [-11.4711, 6.8593]
# Significance:
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 1 (Country Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'reer', 'dmy_EQIimf']
#
# PLR RESULTS:
# Coefficient: 20.9602
# Std Error: 6.6972
# P-value: 0.0017
# 95% CI: [7.8338, 34.0867]
# Significance: ***
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 2 (No Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'lnwages', 'reer']
#
# PLR RESULTS:
# Coefficient: 6.0817
# Std Error: 4.2177
# P-value: 0.1493
# 95% CI: [-2.1849, 14.3484]
# Significance:
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 2 (Country Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'lnwages', 'reer', 'dmy_EQIimf']
#
# PLR RESULTS:
# Coefficient: 20.5701
# Std Error: 7.0696
# P-value: 0.0036
# 95% CI: [6.7136, 34.4265]
# Significance: ***
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 3 (No Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'msch']
#
# PLR RESULTS:
# Coefficient: -12.1774
# Std Error: 5.2489
# P-value: 0.0203
# 95% CI: [-22.4652, -1.8895]
# Significance: **
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 3 (Country Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'msch', 'dmy_EQIimf']
#
# PLR RESULTS:
# Coefficient: 18.5884
# Std Error: 7.2562
# P-value: 0.0104
# 95% CI: [4.3663, 32.8105]
# Significance: **
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 4 (No Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet']
#
# PLR RESULTS:
# Coefficient: -14.2094
# Std Error: 5.3411
# P-value: 0.0078
# 95% CI: [-24.6780, -3.7408]
# Significance: ***
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 4 (Country Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'dmy_EQIimf']
#
# PLR RESULTS:
# Coefficient: 4.5749
# Std Error: 8.8144
# P-value: 0.6037
# 95% CI: [-12.7014, 21.8512]
# Significance:
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 5 (No Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch']
#
# PLR RESULTS:
# Coefficient: -11.5807
# Std Error: 5.3396
# P-value: 0.0301
# 95% CI: [-22.0463, -1.1151]
# Significance: **
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 5 (Country Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'dmy_EQIimf']
#
# PLR RESULTS:
# Coefficient: 7.1763
# Std Error: 9.5837
# P-value: 0.4540
# 95% CI: [-11.6077, 25.9603]
# Significance:
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 6 (No Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer']
#
# PLR RESULTS:
# Coefficient: -7.9334
# Std Error: 4.8046
# P-value: 0.0987
# 95% CI: [-17.3503, 1.4836]
# Significance: *
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 6 (Country Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer', 'dmy_EQIimf']
#
# PLR RESULTS:
# Coefficient: 11.4952
# Std Error: 8.3590
# P-value: 0.1691
# 95% CI: [-4.8883, 27.8788]
# Significance:
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 7 (No Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer']
#
# PLR RESULTS:
# Coefficient: -6.5705
# Std Error: 5.5265
# P-value: 0.2345
# 95% CI: [-17.4025, 4.2615]
# Significance:
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 7 (Country Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer', 'dmy_EQIimf']
#
# PLR RESULTS:
# Coefficient: 13.7166
# Std Error: 8.5828
# P-value: 0.1100
# 95% CI: [-3.1057, 30.5388]
# Significance:
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 1 (No Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'reer']
#
# PLR RESULTS:
# Coefficient: -4.8101
# Std Error: 8.3400
# P-value: 0.5641
# 95% CI: [-21.1566, 11.5364]
# Significance:
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 1 (Country Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'reer', 'dmy_EQIimf']
#
# PLR RESULTS:
# Coefficient: 7.5360
# Std Error: 11.6741
# P-value: 0.5186
# 95% CI: [-15.3452, 30.4172]
# Significance:
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 2 (No Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'lnwages', 'reer']
#
# PLR RESULTS:
# Coefficient: 12.4804
# Std Error: 8.3660
# P-value: 0.1358
# 95% CI: [-3.9171, 28.8778]
# Significance:
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 2 (Country Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'lnwages', 'reer', 'dmy_EQIimf']
#
# PLR RESULTS:
# Coefficient: 17.6294
# Std Error: 11.0913
# P-value: 0.1120
# 95% CI: [-4.1096, 39.3684]
# Significance:
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 3 (No Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'msch']
#
# PLR RESULTS:
# Coefficient: -21.8424
# Std Error: 10.3904
# P-value: 0.0355
# 95% CI: [-42.2076, -1.4773]
# Significance: **
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 3 (Country Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'msch', 'dmy_EQIimf']
#
# PLR RESULTS:
# Coefficient: 1.5429
# Std Error: 10.4747
# P-value: 0.8829
# 95% CI: [-18.9874, 22.0733]
# Significance:
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 4 (No Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet']
#
# PLR RESULTS:
# Coefficient: -35.6425
# Std Error: 13.6246
# P-value: 0.0089
# 95% CI: [-62.3467, -8.9383]
# Significance: ***
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 4 (Country Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'dmy_EQIimf']
#
# PLR RESULTS:
# Coefficient: -16.9291
# Std Error: 11.9820
# P-value: 0.1577
# 95% CI: [-40.4138, 6.5556]
# Significance:
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 5 (No Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch']
#
# PLR RESULTS:
# Coefficient: -26.2428
# Std Error: 10.3210
# P-value: 0.0110
# 95% CI: [-46.4719, -6.0137]
# Significance: **
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 5 (Country Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'dmy_EQIimf']
#
# PLR RESULTS:
# Coefficient: 0.9370
# Std Error: 10.4791
# P-value: 0.9288
# 95% CI: [-19.6021, 21.4761]
# Significance:
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 6 (No Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer']
#
# PLR RESULTS:
# Coefficient: -14.1022
# Std Error: 10.1779
# P-value: 0.1659
# 95% CI: [-34.0509, 5.8465]
# Significance:
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 6 (Country Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer', 'dmy_EQIimf']
#
# PLR RESULTS:
# Coefficient: 5.7196
# Std Error: 11.9342
# P-value: 0.6318
# 95% CI: [-17.6715, 29.1107]
# Significance:
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 7 (No Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer']
#
# PLR RESULTS:
# Coefficient: -10.2096
# Std Error: 8.7267
# P-value: 0.2420
# 95% CI: [-27.3140, 6.8947]
# Significance:
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 7 (Country Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer', 'dmy_EQIimf']
#
# PLR RESULTS:
# Coefficient: -0.9742
# Std Error: 10.8532
# P-value: 0.9285
# 95% CI: [-22.2465, 20.2980]
# Significance:
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 1 (No Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'reer']
#
# PLR RESULTS:
# Coefficient: -14.4769
# Std Error: 5.0195
# P-value: 0.0039
# 95% CI: [-24.3151, -4.6386]
# Significance: ***
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 1 (Country Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'reer', 'dmy_EQIimf']
#
# PLR RESULTS:
# Coefficient: -15.3631
# Std Error: 6.0276
# P-value: 0.0108
# 95% CI: [-27.1772, -3.5489]
# Significance: **
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 2 (No Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'lnwages', 'reer']
#
# PLR RESULTS:
# Coefficient: -5.3913
# Std Error: 4.4578
# P-value: 0.2265
# 95% CI: [-14.1286, 3.3459]
# Significance:
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 2 (Country Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'lnwages', 'reer', 'dmy_EQIimf']
#
# PLR RESULTS:
# Coefficient: -4.9866
# Std Error: 5.3455
# P-value: 0.3509
# 95% CI: [-15.4637, 5.4905]
# Significance:
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 3 (No Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'msch']
#
# PLR RESULTS:
# Coefficient: -27.3079
# Std Error: 6.2340
# P-value: 0.0000
# 95% CI: [-39.5265, -15.0892]
# Significance: ***
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 3 (Country Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'msch', 'dmy_EQIimf']
#
# PLR RESULTS:
# Coefficient: -10.8755
# Std Error: 4.7622
# P-value: 0.0224
# 95% CI: [-20.2094, -1.5415]
# Significance: **
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 4 (No Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet']
#
# PLR RESULTS:
# Coefficient: -30.9981
# Std Error: 6.6390
# P-value: 0.0000
# 95% CI: [-44.0105, -17.9856]
# Significance: ***
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 4 (Country Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'dmy_EQIimf']
#
# PLR RESULTS:
# Coefficient: -10.7179
# Std Error: 5.7674
# P-value: 0.0631
# 95% CI: [-22.0221, 0.5862]
# Significance: *
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 5 (No Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch']
#
# PLR RESULTS:
# Coefficient: -26.2010
# Std Error: 6.4842
# P-value: 0.0001
# 95% CI: [-38.9099, -13.4920]
# Significance: ***
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 5 (Country Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'dmy_EQIimf']
#
# PLR RESULTS:
# Coefficient: -14.2207
# Std Error: 5.0383
# P-value: 0.0048
# 95% CI: [-24.0958, -4.3455]
# Significance: ***
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 6 (No Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer']
#
# PLR RESULTS:
# Coefficient: -16.6462
# Std Error: 5.5362
# P-value: 0.0026
# 95% CI: [-27.4971, -5.7954]
# Significance: ***
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 6 (Country Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer', 'dmy_EQIimf']
#
# PLR RESULTS:
# Coefficient: -10.6502
# Std Error: 5.0022
# P-value: 0.0332
# 95% CI: [-20.4545, -0.8460]
# Significance: **
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 7 (No Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer']
#
# PLR RESULTS:
# Coefficient: -17.7202
# Std Error: 5.5913
# P-value: 0.0015
# 95% CI: [-28.6791, -6.7614]
# Significance: ***
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Export Quality Indicator (IMF)
# SPECIFICATION: GMM Spec 7 (Country Dummies)
# ==================================================
# Data prepared: 660 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer', 'dmy_EQIimf']
#
# PLR RESULTS:
# Coefficient: -15.0112
# Std Error: 6.6040
# P-value: 0.0230
# 95% CI: [-27.9550, -2.0673]
# Significance: **
#
#
# PLR ANALYSIS COMPLETED!
# Total successful analyses: 42

# %%
#9: Feature Importance Analysis

# Feature importance analysis for all models and skill types
print("=" * 80)
print("FEATURE IMPORTANCE ANALYSIS")
print("=" * 80)

def analyze_feature_importance(model, treatment_col, x_cols, model_type, dep_var_name):
    """Extract and display feature importance"""

    if model.models is not None:
        try:
            if model_type == 'PLR':
                fitted_ml_l = model.models['ml_l'][treatment_col][0][0]
                fitted_ml_m = model.models['ml_m'][treatment_col][0][0]

                print(f"\n{model_type} FEATURE IMPORTANCE:")

                # Outcome model (ml_l)
                if hasattr(fitted_ml_l, 'feature_importances_'):
                    # Ensure correct feature names are used based on x_cols and treatment_col
                    # Note: ml_l predicts the outcome (dependent variable), so treatment_col should NOT be included here
                    outcome_features = x_cols
                    if len(fitted_ml_l.feature_importances_) == len(outcome_features):
                        importance_l = pd.Series(
                            fitted_ml_l.feature_importances_,
                            index=outcome_features
                        ).sort_values(ascending=False)

                        print(f"\nOutcome Model ({dep_var_name} Prediction):") # Use dep_var_name
                        for var, imp in importance_l.head(5).items():
                            print(f"  {var}: {imp:.4f}")
                    else:
                         print(f"Warning: Feature importance length mismatch for Outcome Model (ml_l) in {dep_var_name} for {treatment_col}")


                # Treatment model (ml_m)
                if hasattr(fitted_ml_m, 'feature_importances_'):
                     if len(fitted_ml_m.feature_importances_) == len(x_cols):
                        importance_m = pd.Series(
                            fitted_ml_m.feature_importances_,
                            index=x_cols
                        ).sort_values(ascending=False)

                        print(f"\nTreatment Model ({treatment_col} Prediction):") # Dynamically get treatment variable name
                        for var, imp in importance_m.head(5).items():
                            print(f"  {var}: {imp:.4f}")
                     else:
                         print(f"Warning: Feature importance length mismatch for Treatment Model (ml_m) in {dep_var_name} for {treatment_col}")


        except Exception as e:
            print(f"Feature importance extraction failed: {e}")

# Analyze feature importance for all models and skill types
for key in plr_results.keys():
    plr = plr_results[key]

    print(f"\n{'='*60}")
    print(f"FEATURE IMPORTANCE: {plr['dep_var']} ~ {plr['treat_var']}")
    print(f"SPECIFICATION: {MODEL_SPECS[plr['spec_id']]['name']}")
    print(f"{'='*60}")

    # PLR feature importance
    analyze_feature_importance(plr['model'], plr['treat_var'], plr['controls'], 'PLR', plr['dep_var'])
# Out:
# ================================================================================
# FEATURE IMPORTANCE ANALYSIS
# ================================================================================
#
# ============================================================
# FEATURE IMPORTANCE: High Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 1 (No Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (High Skill Prediction):
#   gfcf: 0.2024
#   tariff: 0.1859
#   reer: 0.1679
#   rnd: 0.1404
#   msch: 0.1388
#
# Treatment Model (EQI_IMF Prediction):
#   rnd: 0.8089
#   msch: 0.0707
#   reer: 0.0310
#   mobile: 0.0244
#   gfcf: 0.0233
#
# ============================================================
# FEATURE IMPORTANCE: High Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 1 (Country Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (High Skill Prediction):
#   gfcf: 0.1774
#   reer: 0.1748
#   rnd: 0.1353
#   dmy_EQIimf: 0.1292
#   msch: 0.1272
#
# Treatment Model (EQI_IMF Prediction):
#   dmy_EQIimf: 0.6281
#   msch: 0.1872
#   rnd: 0.1162
#   tariff: 0.0378
#   gfcf: 0.0101
#
# ============================================================
# FEATURE IMPORTANCE: High Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 2 (No Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (High Skill Prediction):
#   lnwages: 0.1906
#   reer: 0.1763
#   gfcf: 0.1696
#   msch: 0.1496
#   rnd: 0.1439
#
# Treatment Model (EQI_IMF Prediction):
#   rnd: 0.7742
#   lnwages: 0.0991
#   msch: 0.0734
#   fdi: 0.0168
#   tariff: 0.0115
#
# ============================================================
# FEATURE IMPORTANCE: High Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 2 (Country Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (High Skill Prediction):
#   reer: 0.1961
#   rnd: 0.1796
#   lnwages: 0.1652
#   gfcf: 0.1226
#   dmy_EQIimf: 0.1008
#
# Treatment Model (EQI_IMF Prediction):
#   dmy_EQIimf: 0.5893
#   rnd: 0.1806
#   msch: 0.1627
#   tariff: 0.0370
#   reer: 0.0103
#
# ============================================================
# FEATURE IMPORTANCE: High Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 3 (No Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (High Skill Prediction):
#   gfcf: 0.2423
#   msch: 0.2211
#   rnd: 0.2204
#   tariff: 0.2108
#   fdi: 0.1055
#
# Treatment Model (EQI_IMF Prediction):
#   rnd: 0.8287
#   msch: 0.0877
#   fdi: 0.0301
#   tariff: 0.0294
#   gfcf: 0.0241
#
# ============================================================
# FEATURE IMPORTANCE: High Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 3 (Country Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (High Skill Prediction):
#   gfcf: 0.2143
#   rnd: 0.1996
#   dmy_EQIimf: 0.1980
#   msch: 0.1921
#   tariff: 0.1190
#
# Treatment Model (EQI_IMF Prediction):
#   dmy_EQIimf: 0.6407
#   msch: 0.1606
#   rnd: 0.1474
#   tariff: 0.0326
#   gfcf: 0.0118
#
# ============================================================
# FEATURE IMPORTANCE: High Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 4 (No Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (High Skill Prediction):
#   rnd: 0.2826
#   gfcf: 0.2420
#   tariff: 0.1691
#   internet: 0.1685
#   fdi: 0.1377
#
# Treatment Model (EQI_IMF Prediction):
#   rnd: 0.8516
#   tariff: 0.0460
#   gfcf: 0.0389
#   fdi: 0.0324
#   internet: 0.0312
#
# ============================================================
# FEATURE IMPORTANCE: High Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 4 (Country Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (High Skill Prediction):
#   dmy_EQIimf: 0.2394
#   rnd: 0.2327
#   gfcf: 0.2145
#   tariff: 0.1325
#   internet: 0.0953
#
# Treatment Model (EQI_IMF Prediction):
#   dmy_EQIimf: 0.6865
#   rnd: 0.2598
#   tariff: 0.0239
#   gfcf: 0.0169
#   internet: 0.0078
#
# ============================================================
# FEATURE IMPORTANCE: High Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 5 (No Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (High Skill Prediction):
#   gfcf: 0.2218
#   rnd: 0.1994
#   msch: 0.1739
#   internet: 0.1609
#   tariff: 0.1556
#
# Treatment Model (EQI_IMF Prediction):
#   rnd: 0.8272
#   msch: 0.0688
#   tariff: 0.0376
#   gfcf: 0.0245
#   internet: 0.0211
#
# ============================================================
# FEATURE IMPORTANCE: High Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 5 (Country Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (High Skill Prediction):
#   rnd: 0.1995
#   gfcf: 0.1992
#   dmy_EQIimf: 0.1572
#   msch: 0.1463
#   internet: 0.1159
#
# Treatment Model (EQI_IMF Prediction):
#   dmy_EQIimf: 0.6555
#   msch: 0.1777
#   rnd: 0.1001
#   tariff: 0.0436
#   internet: 0.0103
#
# ============================================================
# FEATURE IMPORTANCE: High Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 6 (No Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (High Skill Prediction):
#   reer: 0.1916
#   gfcf: 0.1870
#   tariff: 0.1672
#   rnd: 0.1389
#   msch: 0.1212
#
# Treatment Model (EQI_IMF Prediction):
#   rnd: 0.8309
#   msch: 0.0477
#   reer: 0.0308
#   fdi: 0.0262
#   internet: 0.0244
#
# ============================================================
# FEATURE IMPORTANCE: High Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 6 (Country Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (High Skill Prediction):
#   tariff: 0.1675
#   reer: 0.1652
#   msch: 0.1477
#   internet: 0.1207
#   rnd: 0.1191
#
# Treatment Model (EQI_IMF Prediction):
#   dmy_EQIimf: 0.6555
#   rnd: 0.1425
#   msch: 0.1307
#   tariff: 0.0354
#   internet: 0.0176
#
# ============================================================
# FEATURE IMPORTANCE: High Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 7 (No Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (High Skill Prediction):
#   reer: 0.1807
#   gfcf: 0.1724
#   internet: 0.1446
#   tariff: 0.1415
#   msch: 0.1407
#
# Treatment Model (EQI_IMF Prediction):
#   rnd: 0.8413
#   msch: 0.0426
#   reer: 0.0359
#   tariff: 0.0267
#   gfcf: 0.0195
#
# ============================================================
# FEATURE IMPORTANCE: High Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 7 (Country Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (High Skill Prediction):
#   dmy_EQIimf: 0.2013
#   reer: 0.1586
#   msch: 0.1461
#   internet: 0.1328
#   gfcf: 0.1189
#
# Treatment Model (EQI_IMF Prediction):
#   dmy_EQIimf: 0.6760
#   msch: 0.2004
#   rnd: 0.0531
#   tariff: 0.0376
#   internet: 0.0181
#
# ============================================================
# FEATURE IMPORTANCE: Low Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 1 (No Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (Low Skill Prediction):
#   rnd: 0.2656
#   msch: 0.2603
#   reer: 0.1607
#   gfcf: 0.1447
#   mobile: 0.1003
#
# Treatment Model (EQI_IMF Prediction):
#   rnd: 0.8242
#   msch: 0.0533
#   reer: 0.0316
#   gfcf: 0.0270
#   mobile: 0.0261
#
# ============================================================
# FEATURE IMPORTANCE: Low Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 1 (Country Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (Low Skill Prediction):
#   msch: 0.2805
#   rnd: 0.2156
#   dmy_EQIimf: 0.1592
#   reer: 0.1458
#   gfcf: 0.0745
#
# Treatment Model (EQI_IMF Prediction):
#   dmy_EQIimf: 0.6647
#   rnd: 0.1681
#   msch: 0.1151
#   tariff: 0.0207
#   gfcf: 0.0099
#
# ============================================================
# FEATURE IMPORTANCE: Low Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 2 (No Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (Low Skill Prediction):
#   rnd: 0.2733
#   msch: 0.2483
#   lnwages: 0.1266
#   gfcf: 0.1136
#   reer: 0.1023
#
# Treatment Model (EQI_IMF Prediction):
#   rnd: 0.7726
#   lnwages: 0.1130
#   msch: 0.0406
#   fdi: 0.0254
#   reer: 0.0168
#
# ============================================================
# FEATURE IMPORTANCE: Low Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 2 (Country Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (Low Skill Prediction):
#   dmy_EQIimf: 0.2472
#   msch: 0.2244
#   rnd: 0.1947
#   gfcf: 0.0928
#   reer: 0.0807
#
# Treatment Model (EQI_IMF Prediction):
#   dmy_EQIimf: 0.6517
#   msch: 0.2038
#   rnd: 0.0795
#   tariff: 0.0328
#   gfcf: 0.0098
#
# ============================================================
# FEATURE IMPORTANCE: Low Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 3 (No Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (Low Skill Prediction):
#   msch: 0.3031
#   rnd: 0.2952
#   gfcf: 0.2129
#   tariff: 0.1163
#   fdi: 0.0725
#
# Treatment Model (EQI_IMF Prediction):
#   rnd: 0.7992
#   msch: 0.1067
#   gfcf: 0.0350
#   tariff: 0.0303
#   fdi: 0.0287
#
# ============================================================
# FEATURE IMPORTANCE: Low Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 3 (Country Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (Low Skill Prediction):
#   msch: 0.2962
#   dmy_EQIimf: 0.2802
#   rnd: 0.2323
#   gfcf: 0.1176
#   tariff: 0.0400
#
# Treatment Model (EQI_IMF Prediction):
#   dmy_EQIimf: 0.6599
#   msch: 0.1832
#   rnd: 0.1080
#   tariff: 0.0308
#   gfcf: 0.0119
#
# ============================================================
# FEATURE IMPORTANCE: Low Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 4 (No Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (Low Skill Prediction):
#   rnd: 0.4062
#   gfcf: 0.2524
#   tariff: 0.1392
#   fdi: 0.1080
#   internet: 0.0941
#
# Treatment Model (EQI_IMF Prediction):
#   rnd: 0.8541
#   internet: 0.0428
#   gfcf: 0.0413
#   fdi: 0.0325
#   tariff: 0.0293
#
# ============================================================
# FEATURE IMPORTANCE: Low Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 4 (Country Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (Low Skill Prediction):
#   dmy_EQIimf: 0.3625
#   rnd: 0.2753
#   gfcf: 0.1304
#   internet: 0.1007
#   tariff: 0.0922
#
# Treatment Model (EQI_IMF Prediction):
#   dmy_EQIimf: 0.7054
#   rnd: 0.2500
#   tariff: 0.0228
#   internet: 0.0107
#   gfcf: 0.0062
#
# ============================================================
# FEATURE IMPORTANCE: Low Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 5 (No Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (Low Skill Prediction):
#   msch: 0.3178
#   rnd: 0.2942
#   gfcf: 0.1893
#   tariff: 0.0835
#   internet: 0.0725
#
# Treatment Model (EQI_IMF Prediction):
#   rnd: 0.8302
#   msch: 0.0778
#   internet: 0.0270
#   gfcf: 0.0267
#   tariff: 0.0195
#
# ============================================================
# FEATURE IMPORTANCE: Low Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 5 (Country Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (Low Skill Prediction):
#   dmy_EQIimf: 0.3064
#   msch: 0.2483
#   rnd: 0.2052
#   gfcf: 0.0956
#   internet: 0.0765
#
# Treatment Model (EQI_IMF Prediction):
#   dmy_EQIimf: 0.5908
#   msch: 0.1824
#   rnd: 0.1553
#   tariff: 0.0408
#   internet: 0.0188
#
# ============================================================
# FEATURE IMPORTANCE: Low Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 6 (No Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (Low Skill Prediction):
#   msch: 0.3489
#   rnd: 0.2056
#   reer: 0.1991
#   gfcf: 0.1197
#   tariff: 0.0495
#
# Treatment Model (EQI_IMF Prediction):
#   rnd: 0.8123
#   msch: 0.0723
#   reer: 0.0281
#   gfcf: 0.0265
#   fdi: 0.0236
#
# ============================================================
# FEATURE IMPORTANCE: Low Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 6 (Country Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (Low Skill Prediction):
#   msch: 0.2958
#   dmy_EQIimf: 0.2025
#   rnd: 0.1986
#   gfcf: 0.0921
#   reer: 0.0876
#
# Treatment Model (EQI_IMF Prediction):
#   dmy_EQIimf: 0.5961
#   msch: 0.1686
#   rnd: 0.1611
#   tariff: 0.0343
#   internet: 0.0159
#
# ============================================================
# FEATURE IMPORTANCE: Low Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 7 (No Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (Low Skill Prediction):
#   msch: 0.3124
#   rnd: 0.2503
#   gfcf: 0.1238
#   reer: 0.1218
#   internet: 0.0776
#
# Treatment Model (EQI_IMF Prediction):
#   rnd: 0.7840
#   msch: 0.1003
#   reer: 0.0355
#   internet: 0.0254
#   fdi: 0.0222
#
# ============================================================
# FEATURE IMPORTANCE: Low Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 7 (Country Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (Low Skill Prediction):
#   dmy_EQIimf: 0.2417
#   msch: 0.2317
#   rnd: 0.1880
#   reer: 0.1168
#   gfcf: 0.1051
#
# Treatment Model (EQI_IMF Prediction):
#   dmy_EQIimf: 0.6818
#   msch: 0.1632
#   rnd: 0.0950
#   tariff: 0.0305
#   internet: 0.0135
#
# ============================================================
# FEATURE IMPORTANCE: Semi Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 1 (No Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (Semi Skill Prediction):
#   rnd: 0.2949
#   gfcf: 0.2467
#   msch: 0.1131
#   fdi: 0.1126
#   reer: 0.1003
#
# Treatment Model (EQI_IMF Prediction):
#   rnd: 0.8333
#   msch: 0.0489
#   reer: 0.0269
#   gfcf: 0.0261
#   mobile: 0.0252
#
# ============================================================
# FEATURE IMPORTANCE: Semi Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 1 (Country Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (Semi Skill Prediction):
#   rnd: 0.2852
#   gfcf: 0.1891
#   reer: 0.1155
#   dmy_EQIimf: 0.1123
#   fdi: 0.1077
#
# Treatment Model (EQI_IMF Prediction):
#   dmy_EQIimf: 0.6504
#   msch: 0.1585
#   rnd: 0.1427
#   tariff: 0.0235
#   gfcf: 0.0100
#
# ============================================================
# FEATURE IMPORTANCE: Semi Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 2 (No Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (Semi Skill Prediction):
#   rnd: 0.2674
#   gfcf: 0.2315
#   lnwages: 0.1654
#   tariff: 0.0864
#   msch: 0.0753
#
# Treatment Model (EQI_IMF Prediction):
#   rnd: 0.7500
#   lnwages: 0.1103
#   msch: 0.0814
#   fdi: 0.0182
#   reer: 0.0138
#
# ============================================================
# FEATURE IMPORTANCE: Semi Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 2 (Country Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (Semi Skill Prediction):
#   rnd: 0.2775
#   gfcf: 0.2116
#   lnwages: 0.1811
#   msch: 0.0804
#   tariff: 0.0684
#
# Treatment Model (EQI_IMF Prediction):
#   dmy_EQIimf: 0.6358
#   msch: 0.1993
#   rnd: 0.1020
#   tariff: 0.0312
#   gfcf: 0.0093
#
# ============================================================
# FEATURE IMPORTANCE: Semi Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 3 (No Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (Semi Skill Prediction):
#   rnd: 0.3201
#   gfcf: 0.3069
#   msch: 0.1678
#   tariff: 0.1122
#   fdi: 0.0929
#
# Treatment Model (EQI_IMF Prediction):
#   rnd: 0.8161
#   msch: 0.0989
#   tariff: 0.0325
#   fdi: 0.0269
#   gfcf: 0.0257
#
# ============================================================
# FEATURE IMPORTANCE: Semi Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 3 (Country Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (Semi Skill Prediction):
#   rnd: 0.3187
#   gfcf: 0.2228
#   dmy_EQIimf: 0.1950
#   msch: 0.1065
#   tariff: 0.0878
#
# Treatment Model (EQI_IMF Prediction):
#   dmy_EQIimf: 0.5405
#   rnd: 0.2289
#   msch: 0.1779
#   tariff: 0.0385
#   fdi: 0.0073
#
# ============================================================
# FEATURE IMPORTANCE: Semi Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 4 (No Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (Semi Skill Prediction):
#   rnd: 0.3487
#   gfcf: 0.3034
#   tariff: 0.1339
#   fdi: 0.1135
#   internet: 0.1005
#
# Treatment Model (EQI_IMF Prediction):
#   rnd: 0.8587
#   tariff: 0.0455
#   internet: 0.0344
#   gfcf: 0.0314
#   fdi: 0.0301
#
# ============================================================
# FEATURE IMPORTANCE: Semi Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 4 (Country Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (Semi Skill Prediction):
#   rnd: 0.3406
#   gfcf: 0.1924
#   dmy_EQIimf: 0.1885
#   tariff: 0.1570
#   internet: 0.0656
#
# Treatment Model (EQI_IMF Prediction):
#   dmy_EQIimf: 0.5867
#   rnd: 0.3544
#   tariff: 0.0238
#   internet: 0.0199
#   gfcf: 0.0092
#
# ============================================================
# FEATURE IMPORTANCE: Semi Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 5 (No Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (Semi Skill Prediction):
#   rnd: 0.3016
#   gfcf: 0.2681
#   msch: 0.1588
#   internet: 0.1052
#   tariff: 0.0899
#
# Treatment Model (EQI_IMF Prediction):
#   rnd: 0.8587
#   msch: 0.0468
#   tariff: 0.0282
#   gfcf: 0.0265
#   fdi: 0.0260
#
# ============================================================
# FEATURE IMPORTANCE: Semi Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 5 (Country Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (Semi Skill Prediction):
#   rnd: 0.3074
#   gfcf: 0.1961
#   dmy_EQIimf: 0.1645
#   msch: 0.1056
#   tariff: 0.0884
#
# Treatment Model (EQI_IMF Prediction):
#   dmy_EQIimf: 0.6375
#   msch: 0.2022
#   rnd: 0.1021
#   tariff: 0.0379
#   internet: 0.0083
#
# ============================================================
# FEATURE IMPORTANCE: Semi Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 6 (No Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (Semi Skill Prediction):
#   rnd: 0.2804
#   gfcf: 0.2063
#   msch: 0.1488
#   tariff: 0.1135
#   reer: 0.1031
#
# Treatment Model (EQI_IMF Prediction):
#   rnd: 0.8366
#   msch: 0.0404
#   reer: 0.0346
#   fdi: 0.0300
#   tariff: 0.0200
#
# ============================================================
# FEATURE IMPORTANCE: Semi Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 6 (Country Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (Semi Skill Prediction):
#   rnd: 0.2884
#   gfcf: 0.1898
#   dmy_EQIimf: 0.1436
#   reer: 0.0934
#   msch: 0.0905
#
# Treatment Model (EQI_IMF Prediction):
#   dmy_EQIimf: 0.6407
#   msch: 0.1722
#   rnd: 0.1233
#   tariff: 0.0283
#   internet: 0.0167
#
# ============================================================
# FEATURE IMPORTANCE: Semi Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 7 (No Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (Semi Skill Prediction):
#   rnd: 0.3010
#   gfcf: 0.2067
#   msch: 0.1264
#   reer: 0.1019
#   fdi: 0.0934
#
# Treatment Model (EQI_IMF Prediction):
#   rnd: 0.8371
#   msch: 0.0491
#   gfcf: 0.0299
#   fdi: 0.0234
#   internet: 0.0216
#
# ============================================================
# FEATURE IMPORTANCE: Semi Skill ~ EQI_IMF
# SPECIFICATION: GMM Spec 7 (Country Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Outcome Model (Semi Skill Prediction):
#   rnd: 0.3038
#   gfcf: 0.1836
#   reer: 0.1145
#   dmy_EQIimf: 0.1046
#   msch: 0.0973
#
# Treatment Model (EQI_IMF Prediction):
#   dmy_EQIimf: 0.6205
#   msch: 0.1619
#   rnd: 0.1521
#   tariff: 0.0331
#   internet: 0.0156

# %%
#10: Economic Interpretation and Policy Implications

# Economic interpretation and policy implications
print("=" * 80)
print("ECONOMIC INTERPRETATION AND POLICY IMPLICATIONS")
print("=" * 80)

def interpret_results(coef, treat_var, dep_var, method):
    """Provide economic interpretation of results"""

    if treat_var == 'EQI_IMF':
        treatment_name = "Export Quality Indicator (IMF)"
        unit = "unit increase"
    else:
        treatment_name = treat_var
        unit = "unit increase"


    effect_direction = "increases" if coef > 0 else "decreases"
    effect_magnitude = "large" if abs(coef) > 0.1 else "moderate" if abs(coef) > 0.05 else "small"

    # Get descriptive name for dependent variable
    dep_desc = DEPENDENT_VARS.get(dep_var, dep_var)

    interpretation = f"""
    A 1-{unit} in {treatment_name} {effect_direction} {dep_desc} by {abs(coef):.4f} percentage points.
    This represents a {effect_magnitude} {effect_direction[:-1]}ing effect estimated using {method}.
    """

    return interpretation.strip()

# Interpret key results
print("\nKEY FINDINGS:")
print("-" * 40)

# Interpret results for the first specification for each dependent variable
interpreted_keys = []
for dep_var in DEPENDENT_VARS.keys():
    for key, plr in plr_results.items():
        if plr['dep_var'] == dep_var and key.endswith('_spec_1_gmm_nodummy'):
            interpreted_keys.append(key)
            break # Only interpret the first specification for each dependent variable

for i, key in enumerate(interpreted_keys):
    plr = plr_results[key]

    dep_desc = DEPENDENT_VARS[plr['dep_var']]
    treat_desc = TREATMENT_VARS[plr['treat_var']]
    spec_name = MODEL_SPECS[plr['spec_id']]['name']

    print(f"\n{i+1}. {dep_desc} and {treat_desc} ({spec_name})")
    print("   " + "="*50)

    # PLR interpretation
    print(f"   PLR Result: {interpret_results(plr['coef'], plr['treat_var'], plr['dep_var'], 'PLR')}")


print(f"\n\nPOLICY IMPLICATIONS:")
print("-" * 30)
print("1. Export Quality Upgrading and Skilled Employment:")
print("   - Analyze coefficients for High Skill, Low Skill, and Semi Skill employment to understand differential impacts.")
print("   - Positive coefficients suggest export quality improvements boost specific skill levels of employment.")
print("   - Effect sizes indicate magnitude of policy impact for each skill group.")


print("\n2. Robustness:")
print("   - Compare results across different specifications to assess robustness.")
print("   - Multiple specifications ensure result stability.")
# Out:
# ================================================================================
# ECONOMIC INTERPRETATION AND POLICY IMPLICATIONS
# ================================================================================
#
# KEY FINDINGS:
# ----------------------------------------
#
# 1. High Skill Employment and Export Quality Indicator (IMF) (GMM Spec 1 (No Dummies))
#    ==================================================
#    PLR Result: A 1-unit increase in Export Quality Indicator (IMF) decreases High Skill Employment by 2.3059 percentage points.
#     This represents a large decreaseing effect estimated using PLR.
#
# 2. Low Skill Employment and Export Quality Indicator (IMF) (GMM Spec 1 (No Dummies))
#    ==================================================
#    PLR Result: A 1-unit increase in Export Quality Indicator (IMF) decreases Low Skill Employment by 4.8101 percentage points.
#     This represents a large decreaseing effect estimated using PLR.
#
# 3. Semi Skill Employment and Export Quality Indicator (IMF) (GMM Spec 1 (No Dummies))
#    ==================================================
#    PLR Result: A 1-unit increase in Export Quality Indicator (IMF) decreases Semi Skill Employment by 14.4769 percentage points.
#     This represents a large decreaseing effect estimated using PLR.
#
#
# POLICY IMPLICATIONS:
# ------------------------------
# 1. Export Quality Upgrading and Skilled Employment:
#    - Analyze coefficients for High Skill, Low Skill, and Semi Skill employment to understand differential impacts.
#    - Positive coefficients suggest export quality improvements boost specific skill levels of employment.
#    - Effect sizes indicate magnitude of policy impact for each skill group.
#
# 2. Robustness:
#    - Compare results across different specifications to assess robustness.
#    - Multiple specifications ensure result stability.

# %% [markdown]
# ### Average Feature Importance by Skill Type (Outcome Model)
# This cell calculates and displays the average feature importance for the Outcome Model (ml_l) for each skill type across all specifications.

# %%
# Calculate Average Feature Importance

print("=" * 80)
print("AVERAGE FEATURE IMPORTANCE (OUTCOME MODEL)")
print("=" * 80)

# Dictionary to store feature importances for each skill type
skill_type_importances = {dep_var: [] for dep_var in DEPENDENT_VARS.keys()}

# Iterate through all PLR results
for key, plr in plr_results.items():
    dep_var = plr['dep_var']
    treatment_col = plr['treat_var']
    x_cols = plr['controls']
    model = plr['model']

    if model.models is not None:
        try:
            # Outcome model (ml_l)
            fitted_ml_l = model.models['ml_l'][treatment_col][0][0]

            if hasattr(fitted_ml_l, 'feature_importances_'):
                outcome_features = x_cols
                if len(fitted_ml_l.feature_importances_) == len(outcome_features):
                    importance_l = pd.Series(
                        fitted_ml_l.feature_importances_,
                        index=outcome_features
                    )
                    skill_type_importances[dep_var].append(importance_l)
                else:
                    print(f"Warning: Feature importance length mismatch for Outcome Model (ml_l) in {dep_var} for {treatment_col}. Skipping.")


        except Exception as e:
            print(f"Could not extract feature importance for {key}: {e}")
            continue

# Calculate average feature importance for each skill type
average_importances = {}
for dep_var, importances_list in skill_type_importances.items():
    if importances_list:
        # Concatenate all importance series for the skill type and calculate the mean
        all_importances = pd.concat(importances_list, axis=1, sort=False)
        average_importances[dep_var] = all_importances.mean(axis=1).sort_values(ascending=False)
    else:
        average_importances[dep_var] = pd.Series(dtype='float64') # Empty series if no importances

# Display average feature importance
for dep_var, avg_imp in average_importances.items():
    print(f"\nAverage Feature Importance for {DEPENDENT_VARS[dep_var]}:")
    if not avg_imp.empty:
        display(avg_imp)
    else:
        print("  No feature importance data available.")
# Out:
# ================================================================================
# AVERAGE FEATURE IMPORTANCE (OUTCOME MODEL)
# ================================================================================
#
# Average Feature Importance for High Skill Employment:
# gfcf          0.185850
# lnwages       0.177893
# reer          0.176395
# rnd           0.174423
# dmy_EQIimf    0.160305
# msch          0.149626
# tariff        0.135628
# internet      0.129003
# fdi           0.077623
# mobile        0.063513
# dtype: float64
# Average Feature Importance for Low Skill Employment:
# msch          0.280633
# dmy_EQIimf    0.257110
# rnd           0.249997
# gfcf          0.133186
# reer          0.126843
# lnwages       0.090099
# mobile        0.078789
# internet      0.073356
# tariff        0.057449
# fdi           0.040489
# dtype: float64
# Average Feature Importance for Semi Skill Employment:
# rnd           0.302538
# gfcf          0.225354
# lnwages       0.173278
# dmy_EQIimf    0.136998
# msch          0.112294
# tariff        0.094587
# reer          0.088323
# internet      0.078611
# fdi           0.076053
# mobile        0.058002
# dtype: float64
