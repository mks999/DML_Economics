# %% [markdown]
# <a href="https://colab.research.google.com/github/mks999/DML_Economics/blob/main/DML_PLR_and_Feature_Inference_2_9_25_Hi_Semi_Lo_EMP_UV_MHTX_PanelMultiDiD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1.Package Installation and Setup

# Install required packages
# !pip install doubleml scikit-learn pandas numpy openpyxl matplotlib seaborn

# Import libraries
import pandas as pd
import numpy as np
from doubleml import DoubleMLData, DoubleMLPLR, DoubleMLIRM
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

print("=== COMPREHENSIVE DML ANALYSIS: EXPORT QUALITY & EMPLOYMENT ===")
print("Integrated PLR-IRM Framework for Multiple Specifications")
print("Comparable with GMM and Driscoll-Kraay Results")
print("=" * 70)
# Out:
# Collecting doubleml
#   Downloading doubleml-0.10.1-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from doubleml) (1.5.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from doubleml) (1.16.1)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.12/dist-packages (from doubleml) (0.14.5)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from doubleml) (5.24.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->doubleml) (8.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels->doubleml) (1.0.1)
# Downloading doubleml-0.10.1-py3-none-any.whl (471 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.8/471.8 kB 5.0 MB/s eta 0:00:00
# Installing collected packages: doubleml
# Successfully installed doubleml-0.10.1
# === COMPREHENSIVE DML ANALYSIS: EXPORT QUALITY & EMPLOYMENT ===
# Integrated PLR-IRM Framework for Multiple Specifications
# Comparable with GMM and Driscoll-Kraay Results
# ======================================================================

# %%
#2: Data Loading and Preparation

# Load data
file_path = '/content/imputed Hi Lo Semi UV MHTX 31.8.25.xlsx'
df = pd.read_excel(file_path)

print("Data Overview:")
print(f"Shape: {df.shape}")
print(f"Countries: {df['country'].nunique()}")
print(f"Time period: {df['time'].min()}-{df['time'].max()}")
print("\nAvailable columns:")
print(df.columns.tolist())

# Basic data cleaning
df = df.sort_values(['ctryid', 'time']).reset_index(drop=True)

print(f"\nData after sorting: {df.shape}")
print("\nSample data:")
print(df.head(35))
# Out:
# Data Overview:
# Shape: (924, 23)
# Countries: 33
# Time period: 1995-2022
#
# Available columns:
# ['country', 'time', 'mhtx', 'rnd', 'tariff', 'mobile', 'uv_index', 'gfcf', 'fdi', 'lnwages', 'reer', 'd1', 'aggemp', 'ctryid', 'dmy_uvindex', 'dmy_mhtx', 'msch', 'internet', 'covid_dummy', 'L_aggemp', 'High Skill', 'Low Skill', 'Semi Skill']
#
# Data after sorting: (924, 23)
#
# Sample data:
#     country  time     mhtx      rnd  tariff     mobile  uv_index     gfcf  \
# 0   Austria  1995  54.3446  1.53577  10.810    4.82598     75.77  27.1040
# 1   Austria  1996  55.8184  1.58077   6.941    7.52331     62.18  26.4922
# 2   Austria  1997  55.8653  1.65491   5.372   14.55610     60.50  26.3834
# 3   Austria  1998  55.4894  1.73155   3.199   28.74800     61.43  26.2500
# 4   Austria  1999  56.2713  1.84537   2.697   53.18720     76.14  26.2733
# 5   Austria  2000  58.8933  1.88602   2.410   76.36300     67.60  25.9401
# 6   Austria  2001  58.7735  1.99210   3.370   81.35950     66.30  25.4261
# 7   Austria  2002  59.3115  2.06598   2.450   83.37670     69.50  23.7780
# 8   Austria  2003  59.0448  2.17456   2.520   89.58010     82.00  24.4562
# 9   Austria  2004  61.3670  2.16612   2.240   97.80670     91.20  24.2037
# 10  Austria  2005  60.0458  2.37324   2.460  105.32400     94.30  23.9653
# 11  Austria  2006  60.7318  2.35923   2.300  112.25500     98.70  23.8293
# 12  Austria  2007  59.9629  2.41843   2.240  119.49800    111.20  24.7335
# 13  Austria  2008  59.2642  2.56945   1.720  129.98200    122.90  24.7048
# 14  Austria  2009  59.5030  2.59674   1.850  137.05000    113.60  23.0148
# 15  Austria  2010  59.9732  2.72610   2.130  146.37400    110.40  22.8593
# 16  Austria  2011  59.9296  2.66868   1.590  155.19300    121.10  24.3522
# 17  Austria  2012  61.0583  2.91472   1.460  161.19300    114.00  24.2559
# 18  Austria  2013  62.0474  2.95492   1.490  156.51800    117.80  23.9413
# 19  Austria  2014  61.9364  3.08429   2.030  151.56200    117.50  23.8487
# 20  Austria  2015  62.3810  3.04969   2.020  155.86600    100.00  24.0121
# 21  Austria  2016  62.5326  3.11655   2.090  126.81800    100.50  24.4572
# 22  Austria  2017  61.2696  3.05656   1.960  123.43300    105.90  24.9781
# 23  Austria  2018  61.1842  3.09182   1.830  124.24600    115.00  25.8983
# 24  Austria  2019  62.2237  3.13265   1.840  120.78900    111.20  25.5090
# 25  Austria  2020  62.5373  3.20278   1.480  120.31600    114.80  25.6531
# 26  Austria  2021  61.6112  3.26361   1.390  121.96900    129.30  27.6732
# 27  Austria  2022  60.2929  3.20048   1.330  123.43500    137.30  29.2268
# 28  Belgium  1995  52.5238  1.64729  12.910    2.33040     57.22  21.7908
# 29  Belgium  1996  53.1884  1.74299  10.808    4.72351     56.23  21.6307
# 30  Belgium  1997  52.9027  1.80971   9.998    9.59632     55.83  22.3003
# 31  Belgium  1998  53.7402  1.83825   6.781   17.23790     56.32  22.3487
# 32  Belgium  1999  53.9736  1.90565   5.796   31.16720     53.29  22.6890
# 33  Belgium  2000  53.7316  1.93620   2.410   54.84030     65.90  23.7830
# 34  Belgium  2001  55.9727  2.03279   3.370   74.66110     64.90  22.6338
#
#           fdi  lnwages  ...  ctryid  dmy_uvindex  dmy_mhtx     msch  \
# 0    0.760156  23.0443  ...       3        75.77   54.3446  10.6529
# 1    1.832370  23.0658  ...       3        62.18   55.8184  10.7436
# 2    1.260590  23.0707  ...       3        60.50   55.8653  10.8343
# 3    2.106190  23.1061  ...       3        61.43   55.4894  10.9250
# 4    1.374400  23.1523  ...       3        76.14   56.2713  11.0157
# 5    4.333240  23.1848  ...       3        67.60   58.8933  11.1064
# 6    2.895720  23.1759  ...       3        66.30   58.7735  11.1971
# 7    0.065001  23.2058  ...       3        69.50   59.3115  11.2879
# 8    2.375580  23.2491  ...       3        82.00   59.0448  11.3786
# 9    1.064020  23.3028  ...       3        91.20   61.3670  11.4693
# 10  25.830700  23.4000  ...       3        94.30   60.0458  11.5600
# 11   3.144730  23.4700  ...       3        98.70   60.7318  11.5450
# 12  17.805800  23.4857  ...       3       111.20   59.9629  11.5300
# 13   1.468000  23.5460  ...       3       122.90   59.2642  11.4700
# 14   3.581370  23.5953  ...       3       113.60   59.5030  11.6700
# 15  -5.645400  23.6105  ...       3       110.40   59.9732  11.7100
# 16   5.358130  23.6313  ...       3       121.10   59.9296  11.7100
# 17   1.283000  23.6832  ...       3       114.00   61.0583  11.7500
# 18  -0.302633  23.7112  ...       3       117.80   62.0474  11.7900
# 19   0.389557  23.7306  ...       3       117.50   61.9364  12.0100
# 20  -1.804100  23.7671  ...       3       100.00   62.3810  12.0800
# 21  -7.239900  23.8232  ...       3       100.50   62.5326  12.1100
# 22   3.381800  23.8549  ...       3       105.90   61.2696  12.1600
# 23  -6.151190  23.8975  ...       3       115.00   61.1842  12.2100
# 24  -2.852560  23.9629  ...       3       111.20   62.2237  12.2600
# 25  -2.763320  23.9991  ...       3       114.80   62.5373  12.3106
# 26   3.954090  24.0423  ...       3       129.30   61.6112  12.3615
# 27   3.031430  24.1055  ...       3       137.30   60.2929  12.3615
# 28   3.711020  22.7064  ...       4        57.22   52.5238  10.1075
# 29   5.037190  22.7022  ...       4        56.23   53.1884  10.1943
# 30   4.747890  22.7263  ...       4        55.83   52.9027  10.2811
# 31   8.776790  22.7416  ...       4        56.32   53.7402  10.3679
# 32  46.348500  22.7886  ...       4        53.29   53.9736  10.4547
# 33  37.475300  22.8436  ...       4        65.90   53.7316  10.5415
# 34  37.256500  22.8914  ...       4        64.90   55.9727  10.6387
#
#      internet  covid_dummy  L_aggemp  High Skill  Low Skill  Semi Skill
# 0    1.400470            0    56.975        80.6       40.0        66.0
# 1    0.820036            0    56.843        77.1       37.6        65.3
# 2    0.316014            0    55.711        77.5       36.2        64.7
# 3    0.599989            0    55.402        79.5       34.8        65.4
# 4    0.636937            0    55.592        74.7       35.5        65.5
# 5    2.377410            0    56.195        76.1       34.6        65.0
# 6    3.986460            0    55.934        76.5       34.0        64.5
# 7    5.580550            0    55.904        75.4       34.9        63.5
# 8    7.399110            0    56.071        75.0       34.1        64.5
# 9   10.644200            0    56.323        72.2       31.4        62.5
# 10  14.266300            0    54.576        73.6       32.2        62.5
# 11  17.315800            0    55.135        74.3       32.9        62.6
# 12  19.549300            0    55.834        75.1       34.8        63.5
# 13  20.773100            0    56.893        74.0       34.5        64.4
# 14  22.510600            0    57.558        73.9       33.5        63.5
# 15  24.511400            0    57.107        73.6       33.4        63.7
# 16  24.992600            0    57.343        74.1       33.8        63.6
# 17  25.264500            0    57.558        74.8       33.1        63.6
# 18  26.322300            0    57.670        74.4       32.4        63.4
# 19  27.597700            0    57.538        73.6       32.7        60.8
# 20  28.406900            0    57.160        73.8       32.3        60.2
# 21  28.877600            0    57.115        74.0       32.8        60.1
# 22  28.542600            0    57.427        74.7       32.2        60.3
# 23  28.515000            0    57.703        74.1       32.8        61.1
# 24  28.363200            0    58.298        74.3       33.0        60.9
# 25  29.210600            1    58.514        74.2       33.0        59.0
# 26  29.253700            1    57.651        73.6       32.6        58.3
# 27  29.234300            1    57.202        77.2       33.3        61.1
# 28   0.892304            0    45.476        76.9       28.8        57.8
# 29   1.347640            0    45.813        76.3       27.6        57.2
# 30   1.083600            0    45.626        76.7       27.2        57.9
# 31   0.107219            0    45.999        77.2       28.1        57.6
# 32   0.224956            0    46.112        78.7       29.2        58.8
# 33   1.406740            0    47.421        79.4       30.4        59.4
# 34   4.471770            0    48.849        77.4       28.3        59.7
#
# [35 rows x 23 columns]

# %%
# 3: Model Specifications Setup

# Define comprehensive model specifications
MODEL_SPECS = {
    'spec_1_gmm_nodummy': {
        'name': 'GMM Spec 1 (No Dummies)',
        'controls': ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'reer'],
        'dummies': [],
        'description': 'Comparable to GMM Spec 1 without dummies'
    },
    'spec_1_gmm_ctrydummy': {
        'name': 'GMM Spec 1 (Country Dummies)',
        'controls': ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'reer'],
        'dummies': ['dmy_treatment'],
        'description': 'Comparable to GMM Spec 1 with country dummies'
    },
    'spec_2_gmm_nodummy': {
        'name': 'GMM Spec 2 (No Dummies)',
        'controls': ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'lnwages', 'reer'],
        'dummies': [],
        'description': 'Comparable to GMM Spec 2 without dummies'
    },
    'spec_2_gmm_ctrydummy': {
        'name': 'GMM Spec 2 (Country Dummies)',
        'controls': ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'lnwages', 'reer'],
        'dummies': ['dmy_treatment'],
        'description': 'Comparable to GMM Spec 2 with country dummies'
    },
     'spec_3_gmm_nodummy': {
        'name': 'GMM Spec 3 (No Dummies)',
        'controls': ['fdi', 'gfcf', 'rnd', 'tariff', 'msch'],
        'dummies': [],
        'description': 'Comparable to GMM Spec 3 without dummies'
    },
    'spec_3_gmm_ctrydummy': {
        'name': 'GMM Spec 3 (Country Dummies)',
        'controls': ['fdi', 'gfcf', 'rnd', 'tariff', 'msch'],
        'dummies': ['dmy_treatment'],
        'description': 'Comparable to GMM Spec 3 with country dummies'
    },
      'spec_4_gmm_nodummy': {
        'name': 'GMM Spec 4 (No Dummies)',
        'controls': ['fdi', 'gfcf', 'rnd', 'tariff', 'internet'],
        'dummies': [],
        'description': 'Comparable to GMM Spec 4 without dummies'
    },
    'spec_4_gmm_ctrydummy': {
        'name': 'GMM Spec 4 (Country Dummies)',
        'controls': ['fdi', 'gfcf', 'rnd', 'tariff', 'internet'],
        'dummies': ['dmy_treatment'],
        'description': 'Comparable to GMM Spec 4 with country dummies'
    },
      'spec_5_gmm_nodummy': {
        'name': 'GMM Spec 5 (No Dummies)',
        'controls': ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch'],
        'dummies': [],
        'description': 'Comparable to GMM Spec 5 with dummies'
    },
    'spec_5_gmm_ctrydummy': {
        'name': 'GMM Spec 5 (Country Dummies)',
        'controls': ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch'],
        'dummies': ['dmy_treatment'],
        'description': 'Comparable to GMM Spec 5 with country dummies'
    },
      'spec_6_gmm_nodummy': {
        'name': 'GMM Spec 6 (No Dummies)',
        'controls': ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer'],
        'dummies': [],
        'description': 'Comparable to GMM Spec 6 without dummies'
    },
    'spec_6_gmm_ctrydummy': {
        'name': 'GMM Spec 6 (Country Dummies)',
        'controls': ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer'],
        'dummies': ['dmy_treatment'],
        'description': 'Comparable to GMM Spec 6 with country dummies'
    },
     'spec_7_gmm_nodummy': {
        'name': 'GMM Spec 7 (No Dummies)',
        'controls': ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer'],
        'dummies': [],
        'description': 'Comparable to GMM Spec 7 without dummies'
    },
    'spec_7_gmm_ctrydummy': {
        'name': 'GMM Spec 7 (Country Dummies)',
        'controls': ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer'],
        'dummies': ['dmy_treatment'],
        'description': 'Comparable to GMM Spec 7 with country dummies'
    }
}


# Define analysis framework
DEPENDENT_VARS = {
    'High Skill': 'High Skill Employment',
    'Low Skill': 'Low Skill Employment',
    'Semi Skill': 'Semi Skill Employment',
}

TREATMENT_VARS = {
    'uv_index': 'Export Unit Value Index (Quality)',
    'mhtx': 'Manufacturing High-Technology Exports'
}

print("MODEL SPECIFICATIONS:")
print("=" * 50)
for spec_id, spec in MODEL_SPECS.items():
    print(f"{spec_id}: {spec['name']}")
    print(f"  Description: {spec['description']}")
    print(f"  Controls: {len(spec['controls'])} variables")
    print(f"  Dummies: {spec['dummies']}")
    print()

print("ANALYSIS FRAMEWORK:")
print(f"Dependent Variables: {list(DEPENDENT_VARS.keys())}")
print(f"Treatment Variables: {list(TREATMENT_VARS.keys())}")
print(f"Total Combinations: {len(DEPENDENT_VARS) * len(TREATMENT_VARS) * len(MODEL_SPECS)}")
# Out:
# MODEL SPECIFICATIONS:
# ==================================================
# spec_1_gmm_nodummy: GMM Spec 1 (No Dummies)
#   Description: Comparable to GMM Spec 1 without dummies
#   Controls: 7 variables
#   Dummies: []
#
# spec_1_gmm_ctrydummy: GMM Spec 1 (Country Dummies)
#   Description: Comparable to GMM Spec 1 with country dummies
#   Controls: 7 variables
#   Dummies: ['dmy_treatment']
#
# spec_2_gmm_nodummy: GMM Spec 2 (No Dummies)
#   Description: Comparable to GMM Spec 2 without dummies
#   Controls: 8 variables
#   Dummies: []
#
# spec_2_gmm_ctrydummy: GMM Spec 2 (Country Dummies)
#   Description: Comparable to GMM Spec 2 with country dummies
#   Controls: 8 variables
#   Dummies: ['dmy_treatment']
#
# spec_3_gmm_nodummy: GMM Spec 3 (No Dummies)
#   Description: Comparable to GMM Spec 3 without dummies
#   Controls: 5 variables
#   Dummies: []
#
# spec_3_gmm_ctrydummy: GMM Spec 3 (Country Dummies)
#   Description: Comparable to GMM Spec 3 with country dummies
#   Controls: 5 variables
#   Dummies: ['dmy_treatment']
#
# spec_4_gmm_nodummy: GMM Spec 4 (No Dummies)
#   Description: Comparable to GMM Spec 4 without dummies
#   Controls: 5 variables
#   Dummies: []
#
# spec_4_gmm_ctrydummy: GMM Spec 4 (Country Dummies)
#   Description: Comparable to GMM Spec 4 with country dummies
#   Controls: 5 variables
#   Dummies: ['dmy_treatment']
#
# spec_5_gmm_nodummy: GMM Spec 5 (No Dummies)
#   Description: Comparable to GMM Spec 5 with dummies
#   Controls: 6 variables
#   Dummies: []
#
# spec_5_gmm_ctrydummy: GMM Spec 5 (Country Dummies)
#   Description: Comparable to GMM Spec 5 with country dummies
#   Controls: 6 variables
#   Dummies: ['dmy_treatment']
#
# spec_6_gmm_nodummy: GMM Spec 6 (No Dummies)
#   Description: Comparable to GMM Spec 6 without dummies
#   Controls: 7 variables
#   Dummies: []
#
# spec_6_gmm_ctrydummy: GMM Spec 6 (Country Dummies)
#   Description: Comparable to GMM Spec 6 with country dummies
#   Controls: 7 variables
#   Dummies: ['dmy_treatment']
#
# spec_7_gmm_nodummy: GMM Spec 7 (No Dummies)
#   Description: Comparable to GMM Spec 7 without dummies
#   Controls: 7 variables
#   Dummies: []
#
# spec_7_gmm_ctrydummy: GMM Spec 7 (Country Dummies)
#   Description: Comparable to GMM Spec 7 with country dummies
#   Controls: 7 variables
#   Dummies: ['dmy_treatment']
#
# ANALYSIS FRAMEWORK:
# Dependent Variables: ['High Skill', 'Low Skill', 'Semi Skill']
# Treatment Variables: ['uv_index', 'mhtx']
# Total Combinations: 84

# %%
# 4: Analysis Functions

def prepare_data_for_analysis(df, y_col, treatment_col, spec_name):
    """
    Prepare data for DML analysis based on specification
    """
    spec = MODEL_SPECS[spec_name]

    # Start with base controls
    x_cols = spec['controls'].copy()

    # Add dummies if specified
    if spec['dummies']:
        for dummy in spec['dummies']:
            if dummy == 'dmy_treatment':
                # Dynamically set treatment dummy
                if treatment_col == 'mhtx':
                    x_cols.append('dmy_mhtx')
                elif treatment_col == 'uv_index':
                    x_cols.append('dmy_uvindex')
                elif treatment_col == 'EQI_IMF':
                    x_cols.append('dmy_EQIimf')
            else:
                x_cols.append(dummy)

    # Select required columns
    required_cols = [y_col, treatment_col] + x_cols

    # Check available columns
    available_cols = [col for col in required_cols if col in df.columns]
    missing_cols = [col for col in required_cols if col not in df.columns]

    if missing_cols:
        print(f"Warning: Missing columns {missing_cols}")
        print(f"Available columns: {available_cols}")

    # Use available columns
    df_clean = df[available_cols].dropna()
    actual_x_cols = [col for col in x_cols if col in df.columns]

    return df_clean, actual_x_cols, len(df) - len(df_clean)

def run_plr_analysis(df_clean, y_col, treatment_col, x_cols, spec_name):
    """
    Run PLR analysis
    """
    # Create DoubleML data object
    dml_data = DoubleMLData(df_clean, y_col=y_col, d_cols=treatment_col, x_cols=x_cols)

    # Define ML models
    ml_l = GradientBoostingRegressor(n_estimators=200, max_depth=4, random_state=42)
    ml_m = RandomForestRegressor(n_estimators=200, max_depth=4, random_state=42)

    # Fit PLR model
    dml_plr = DoubleMLPLR(dml_data, ml_l=ml_l, ml_m=ml_m, n_folds=5, n_rep=3)
    dml_plr.fit(store_models=True)

    return dml_plr

print("Analysis functions defined successfully!")
print("Functions available:")
print("- prepare_data_for_analysis(): Data preparation for each specification")
print("- run_plr_analysis(): PLR model estimation")
# Out:
# Analysis functions defined successfully!
# Functions available:
# - prepare_data_for_analysis(): Data preparation for each specification
# - run_plr_analysis(): PLR model estimation

# %%
#5: Main Analysis Loop - PLR Results

# Initialize results storage
plr_results = {}
data_info = {}

print("=" * 70)
print("PLR ANALYSIS RESULTS")
print("=" * 70)

# Run analysis for each combination
for dep_var, dep_desc in DEPENDENT_VARS.items():
    if dep_var not in df.columns:
        print(f"Skipping {dep_var} - not available in dataset")
        continue

    for treat_var, treat_desc in TREATMENT_VARS.items():
        for spec_id, spec in MODEL_SPECS.items(): # Iterate through all new specifications

            print(f"\n{'='*50}")
            print(f"ANALYSIS: {dep_desc} ~ {treat_desc}")
            print(f"SPECIFICATION: {spec['name']}")
            print(f"{'='*50}")

            try:
                # Prepare data
                df_clean, x_cols, missing_obs = prepare_data_for_analysis(
                    df, dep_var, treat_var, spec_id
                )

                print(f"Data prepared: {len(df_clean)} obs, {missing_obs} dropped")
                print(f"Controls used: {x_cols}")

                # Run PLR
                dml_plr = run_plr_analysis(df_clean, dep_var, treat_var, x_cols, spec_id)

                # Store results
                key = f"{dep_var}_{treat_var}_{spec_id}"
                plr_results[key] = {
                    'model': dml_plr,
                    'coef': dml_plr.coef[0], # Access the scalar value
                    'se': dml_plr.se[0],     # Access the scalar value
                    'pval': dml_plr.pval[0],   # Access the scalar value
                    'ci_lower': dml_plr.coef[0] - 1.96 * dml_plr.se[0], # Access scalar values
                    'ci_upper': dml_plr.coef[0] + 1.96 * dml_plr.se[0], # Access scalar values
                    'n_obs': len(df_clean),
                    'dep_var': dep_var,
                    'treat_var': treat_var,
                    'spec_id': spec_id,
                    'controls': x_cols
                }

                data_info[key] = {
                    'df_clean': df_clean,
                    'x_cols': x_cols
                }

                # Display results - format the scalar values
                print(f"\nPLR RESULTS:")
                print(f"Coefficient: {plr_results[key]['coef']:.4f}")
                print(f"Std Error: {plr_results[key]['se']:.4f}")
                print(f"P-value: {plr_results[key]['pval']:.4f}")
                print(f"95% CI: [{plr_results[key]['ci_lower']:.4f}, {plr_results[key]['ci_upper']:.4f}]")

                significance = "***" if plr_results[key]['pval'] < 0.01 else "**" if plr_results[key]['pval'] < 0.05 else "*" if plr_results[key]['pval'] < 0.1 else ""
                print(f"Significance: {significance}")

            except Exception as e:
                print(f"Error in analysis: {str(e)}")
                continue

print(f"\n\nPLR ANALYSIS COMPLETED!")
print(f"Total successful analyses: {len(plr_results)}")
# Out:
# ======================================================================
# PLR ANALYSIS RESULTS
# ======================================================================
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 1 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'reer']
#
# PLR RESULTS:
# Coefficient: -0.0272
# Std Error: 0.0080
# P-value: 0.0006
# 95% CI: [-0.0428, -0.0116]
# Significance: ***
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 1 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'reer', 'dmy_uvindex']
#
# PLR RESULTS:
# Coefficient: -0.0366
# Std Error: 0.0107
# P-value: 0.0006
# 95% CI: [-0.0575, -0.0157]
# Significance: ***
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 2 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'lnwages', 'reer']
#
# PLR RESULTS:
# Coefficient: -0.0170
# Std Error: 0.0074
# P-value: 0.0221
# 95% CI: [-0.0316, -0.0024]
# Significance: **
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 2 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'lnwages', 'reer', 'dmy_uvindex']
#
# PLR RESULTS:
# Coefficient: -0.0213
# Std Error: 0.0093
# P-value: 0.0217
# 95% CI: [-0.0396, -0.0031]
# Significance: **
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 3 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'msch']
#
# PLR RESULTS:
# Coefficient: -0.0155
# Std Error: 0.0068
# P-value: 0.0219
# 95% CI: [-0.0287, -0.0022]
# Significance: **
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 3 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'msch', 'dmy_uvindex']
#
# PLR RESULTS:
# Coefficient: -0.0303
# Std Error: 0.0099
# P-value: 0.0022
# 95% CI: [-0.0496, -0.0109]
# Significance: ***
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 4 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet']
#
# PLR RESULTS:
# Coefficient: -0.0220
# Std Error: 0.0091
# P-value: 0.0157
# 95% CI: [-0.0398, -0.0041]
# Significance: **
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 4 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'dmy_uvindex']
#
# PLR RESULTS:
# Coefficient: -0.0287
# Std Error: 0.0120
# P-value: 0.0169
# 95% CI: [-0.0522, -0.0051]
# Significance: **
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 5 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch']
#
# PLR RESULTS:
# Coefficient: -0.0146
# Std Error: 0.0080
# P-value: 0.0673
# 95% CI: [-0.0302, 0.0010]
# Significance: *
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 5 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'dmy_uvindex']
#
# PLR RESULTS:
# Coefficient: -0.0338
# Std Error: 0.0123
# P-value: 0.0060
# 95% CI: [-0.0579, -0.0097]
# Significance: ***
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 6 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer']
#
# PLR RESULTS:
# Coefficient: -0.0212
# Std Error: 0.0086
# P-value: 0.0135
# 95% CI: [-0.0379, -0.0044]
# Significance: **
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 6 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer', 'dmy_uvindex']
#
# PLR RESULTS:
# Coefficient: -0.0274
# Std Error: 0.0120
# P-value: 0.0222
# 95% CI: [-0.0508, -0.0039]
# Significance: **
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 7 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer']
#
# PLR RESULTS:
# Coefficient: -0.0169
# Std Error: 0.0073
# P-value: 0.0217
# 95% CI: [-0.0312, -0.0025]
# Significance: **
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 7 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer', 'dmy_uvindex']
#
# PLR RESULTS:
# Coefficient: -0.0308
# Std Error: 0.0116
# P-value: 0.0080
# 95% CI: [-0.0536, -0.0080]
# Significance: ***
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 1 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'reer']
#
# PLR RESULTS:
# Coefficient: -0.0360
# Std Error: 0.0125
# P-value: 0.0039
# 95% CI: [-0.0605, -0.0115]
# Significance: ***
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 1 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'reer', 'dmy_mhtx']
#
# PLR RESULTS:
# Coefficient: 0.0288
# Std Error: 0.0122
# P-value: 0.0181
# 95% CI: [0.0049, 0.0526]
# Significance: **
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 2 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'lnwages', 'reer']
#
# PLR RESULTS:
# Coefficient: -0.0097
# Std Error: 0.0108
# P-value: 0.3662
# 95% CI: [-0.0309, 0.0114]
# Significance:
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 2 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'lnwages', 'reer', 'dmy_mhtx']
#
# PLR RESULTS:
# Coefficient: 0.0365
# Std Error: 0.0133
# P-value: 0.0062
# 95% CI: [0.0104, 0.0627]
# Significance: ***
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 3 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'msch']
#
# PLR RESULTS:
# Coefficient: -0.0539
# Std Error: 0.0137
# P-value: 0.0001
# 95% CI: [-0.0808, -0.0271]
# Significance: ***
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 3 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'msch', 'dmy_mhtx']
#
# PLR RESULTS:
# Coefficient: 0.0352
# Std Error: 0.0143
# P-value: 0.0140
# 95% CI: [0.0071, 0.0633]
# Significance: **
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 4 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet']
#
# PLR RESULTS:
# Coefficient: -0.0574
# Std Error: 0.0156
# P-value: 0.0002
# 95% CI: [-0.0880, -0.0268]
# Significance: ***
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 4 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'dmy_mhtx']
#
# PLR RESULTS:
# Coefficient: 0.0337
# Std Error: 0.0138
# P-value: 0.0142
# 95% CI: [0.0068, 0.0607]
# Significance: **
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 5 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch']
#
# PLR RESULTS:
# Coefficient: -0.0507
# Std Error: 0.0146
# P-value: 0.0005
# 95% CI: [-0.0794, -0.0221]
# Significance: ***
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 5 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'dmy_mhtx']
#
# PLR RESULTS:
# Coefficient: 0.0467
# Std Error: 0.0140
# P-value: 0.0009
# 95% CI: [0.0191, 0.0742]
# Significance: ***
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 6 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer']
#
# PLR RESULTS:
# Coefficient: -0.0303
# Std Error: 0.0129
# P-value: 0.0188
# 95% CI: [-0.0556, -0.0050]
# Significance: **
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 6 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer', 'dmy_mhtx']
#
# PLR RESULTS:
# Coefficient: 0.0380
# Std Error: 0.0122
# P-value: 0.0019
# 95% CI: [0.0141, 0.0618]
# Significance: ***
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 7 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer']
#
# PLR RESULTS:
# Coefficient: -0.0245
# Std Error: 0.0121
# P-value: 0.0424
# 95% CI: [-0.0482, -0.0008]
# Significance: **
#
# ==================================================
# ANALYSIS: High Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 7 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer', 'dmy_mhtx']
#
# PLR RESULTS:
# Coefficient: 0.0368
# Std Error: 0.0127
# P-value: 0.0037
# 95% CI: [0.0120, 0.0617]
# Significance: ***
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 1 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'reer']
#
# PLR RESULTS:
# Coefficient: -0.0148
# Std Error: 0.0170
# P-value: 0.3830
# 95% CI: [-0.0480, 0.0184]
# Significance:
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 1 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'reer', 'dmy_uvindex']
#
# PLR RESULTS:
# Coefficient: 0.0083
# Std Error: 0.0148
# P-value: 0.5758
# 95% CI: [-0.0207, 0.0372]
# Significance:
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 2 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'lnwages', 'reer']
#
# PLR RESULTS:
# Coefficient: 0.0065
# Std Error: 0.0139
# P-value: 0.6413
# 95% CI: [-0.0208, 0.0337]
# Significance:
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 2 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'lnwages', 'reer', 'dmy_uvindex']
#
# PLR RESULTS:
# Coefficient: 0.0186
# Std Error: 0.0120
# P-value: 0.1220
# 95% CI: [-0.0050, 0.0421]
# Significance:
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 3 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'msch']
#
# PLR RESULTS:
# Coefficient: 0.0060
# Std Error: 0.0127
# P-value: 0.6365
# 95% CI: [-0.0189, 0.0309]
# Significance:
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 3 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'msch', 'dmy_uvindex']
#
# PLR RESULTS:
# Coefficient: 0.0314
# Std Error: 0.0119
# P-value: 0.0085
# 95% CI: [0.0080, 0.0547]
# Significance: ***
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 4 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet']
#
# PLR RESULTS:
# Coefficient: 0.0069
# Std Error: 0.0192
# P-value: 0.7181
# 95% CI: [-0.0307, 0.0445]
# Significance:
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 4 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'dmy_uvindex']
#
# PLR RESULTS:
# Coefficient: -0.0093
# Std Error: 0.0193
# P-value: 0.6309
# 95% CI: [-0.0471, 0.0286]
# Significance:
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 5 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch']
#
# PLR RESULTS:
# Coefficient: 0.0020
# Std Error: 0.0136
# P-value: 0.8840
# 95% CI: [-0.0247, 0.0287]
# Significance:
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 5 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'dmy_uvindex']
#
# PLR RESULTS:
# Coefficient: 0.0226
# Std Error: 0.0163
# P-value: 0.1661
# 95% CI: [-0.0094, 0.0546]
# Significance:
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 6 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer']
#
# PLR RESULTS:
# Coefficient: -0.0027
# Std Error: 0.0143
# P-value: 0.8516
# 95% CI: [-0.0308, 0.0254]
# Significance:
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 6 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer', 'dmy_uvindex']
#
# PLR RESULTS:
# Coefficient: 0.0060
# Std Error: 0.0145
# P-value: 0.6810
# 95% CI: [-0.0225, 0.0344]
# Significance:
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 7 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer']
#
# PLR RESULTS:
# Coefficient: -0.0179
# Std Error: 0.0142
# P-value: 0.2087
# 95% CI: [-0.0458, 0.0100]
# Significance:
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 7 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer', 'dmy_uvindex']
#
# PLR RESULTS:
# Coefficient: 0.0051
# Std Error: 0.0131
# P-value: 0.6959
# 95% CI: [-0.0205, 0.0307]
# Significance:
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 1 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'reer']
#
# PLR RESULTS:
# Coefficient: -0.1179
# Std Error: 0.0238
# P-value: 0.0000
# 95% CI: [-0.1645, -0.0712]
# Significance: ***
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 1 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'reer', 'dmy_mhtx']
#
# PLR RESULTS:
# Coefficient: 0.0269
# Std Error: 0.0193
# P-value: 0.1637
# 95% CI: [-0.0109, 0.0647]
# Significance:
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 2 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'lnwages', 'reer']
#
# PLR RESULTS:
# Coefficient: -0.0610
# Std Error: 0.0212
# P-value: 0.0040
# 95% CI: [-0.1024, -0.0195]
# Significance: ***
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 2 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'lnwages', 'reer', 'dmy_mhtx']
#
# PLR RESULTS:
# Coefficient: 0.0244
# Std Error: 0.0168
# P-value: 0.1466
# 95% CI: [-0.0085, 0.0573]
# Significance:
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 3 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'msch']
#
# PLR RESULTS:
# Coefficient: -0.1428
# Std Error: 0.0271
# P-value: 0.0000
# 95% CI: [-0.1959, -0.0897]
# Significance: ***
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 3 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'msch', 'dmy_mhtx']
#
# PLR RESULTS:
# Coefficient: 0.0141
# Std Error: 0.0212
# P-value: 0.5076
# 95% CI: [-0.0276, 0.0557]
# Significance:
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 4 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet']
#
# PLR RESULTS:
# Coefficient: -0.1713
# Std Error: 0.0364
# P-value: 0.0000
# 95% CI: [-0.2427, -0.1000]
# Significance: ***
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 4 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'dmy_mhtx']
#
# PLR RESULTS:
# Coefficient: 0.0300
# Std Error: 0.0280
# P-value: 0.2840
# 95% CI: [-0.0249, 0.0850]
# Significance:
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 5 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch']
#
# PLR RESULTS:
# Coefficient: -0.1508
# Std Error: 0.0276
# P-value: 0.0000
# 95% CI: [-0.2050, -0.0966]
# Significance: ***
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 5 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'dmy_mhtx']
#
# PLR RESULTS:
# Coefficient: 0.0116
# Std Error: 0.0188
# P-value: 0.5389
# 95% CI: [-0.0253, 0.0484]
# Significance:
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 6 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer']
#
# PLR RESULTS:
# Coefficient: -0.1199
# Std Error: 0.0231
# P-value: 0.0000
# 95% CI: [-0.1652, -0.0746]
# Significance: ***
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 6 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer', 'dmy_mhtx']
#
# PLR RESULTS:
# Coefficient: 0.0240
# Std Error: 0.0193
# P-value: 0.2138
# 95% CI: [-0.0139, 0.0619]
# Significance:
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 7 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer']
#
# PLR RESULTS:
# Coefficient: -0.1156
# Std Error: 0.0227
# P-value: 0.0000
# 95% CI: [-0.1601, -0.0710]
# Significance: ***
#
# ==================================================
# ANALYSIS: Low Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 7 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer', 'dmy_mhtx']
#
# PLR RESULTS:
# Coefficient: -0.0048
# Std Error: 0.0193
# P-value: 0.8035
# 95% CI: [-0.0426, 0.0330]
# Significance:
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 1 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'reer']
#
# PLR RESULTS:
# Coefficient: -0.0316
# Std Error: 0.0082
# P-value: 0.0001
# 95% CI: [-0.0478, -0.0155]
# Significance: ***
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 1 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'reer', 'dmy_uvindex']
#
# PLR RESULTS:
# Coefficient: -0.0100
# Std Error: 0.0093
# P-value: 0.2836
# 95% CI: [-0.0283, 0.0083]
# Significance:
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 2 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'lnwages', 'reer']
#
# PLR RESULTS:
# Coefficient: -0.0180
# Std Error: 0.0064
# P-value: 0.0046
# 95% CI: [-0.0305, -0.0056]
# Significance: ***
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 2 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'lnwages', 'reer', 'dmy_uvindex']
#
# PLR RESULTS:
# Coefficient: -0.0068
# Std Error: 0.0078
# P-value: 0.3876
# 95% CI: [-0.0221, 0.0086]
# Significance:
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 3 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'msch']
#
# PLR RESULTS:
# Coefficient: -0.0108
# Std Error: 0.0068
# P-value: 0.1103
# 95% CI: [-0.0241, 0.0025]
# Significance:
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 3 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'msch', 'dmy_uvindex']
#
# PLR RESULTS:
# Coefficient: 0.0058
# Std Error: 0.0107
# P-value: 0.5902
# 95% CI: [-0.0152, 0.0268]
# Significance:
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 4 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet']
#
# PLR RESULTS:
# Coefficient: -0.0241
# Std Error: 0.0090
# P-value: 0.0072
# 95% CI: [-0.0416, -0.0065]
# Significance: ***
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 4 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'dmy_uvindex']
#
# PLR RESULTS:
# Coefficient: -0.0224
# Std Error: 0.0107
# P-value: 0.0362
# 95% CI: [-0.0434, -0.0014]
# Significance: **
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 5 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch']
#
# PLR RESULTS:
# Coefficient: -0.0218
# Std Error: 0.0080
# P-value: 0.0064
# 95% CI: [-0.0375, -0.0061]
# Significance: ***
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 5 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'dmy_uvindex']
#
# PLR RESULTS:
# Coefficient: -0.0238
# Std Error: 0.0101
# P-value: 0.0182
# 95% CI: [-0.0436, -0.0040]
# Significance: **
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 6 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer']
#
# PLR RESULTS:
# Coefficient: -0.0263
# Std Error: 0.0080
# P-value: 0.0010
# 95% CI: [-0.0419, -0.0106]
# Significance: ***
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 6 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer', 'dmy_uvindex']
#
# PLR RESULTS:
# Coefficient: -0.0193
# Std Error: 0.0094
# P-value: 0.0395
# 95% CI: [-0.0376, -0.0009]
# Significance: **
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 7 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer']
#
# PLR RESULTS:
# Coefficient: -0.0248
# Std Error: 0.0077
# P-value: 0.0013
# 95% CI: [-0.0400, -0.0097]
# Significance: ***
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Export Unit Value Index (Quality)
# SPECIFICATION: GMM Spec 7 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer', 'dmy_uvindex']
#
# PLR RESULTS:
# Coefficient: -0.0208
# Std Error: 0.0103
# P-value: 0.0434
# 95% CI: [-0.0410, -0.0006]
# Significance: **
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 1 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'reer']
#
# PLR RESULTS:
# Coefficient: -0.0255
# Std Error: 0.0158
# P-value: 0.1052
# 95% CI: [-0.0564, 0.0054]
# Significance:
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 1 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'reer', 'dmy_mhtx']
#
# PLR RESULTS:
# Coefficient: 0.0051
# Std Error: 0.0117
# P-value: 0.6600
# 95% CI: [-0.0178, 0.0281]
# Significance:
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 2 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'lnwages', 'reer']
#
# PLR RESULTS:
# Coefficient: 0.0044
# Std Error: 0.0114
# P-value: 0.6966
# 95% CI: [-0.0178, 0.0267]
# Significance:
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 2 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'mobile', 'msch', 'lnwages', 'reer', 'dmy_mhtx']
#
# PLR RESULTS:
# Coefficient: 0.0250
# Std Error: 0.0153
# P-value: 0.1022
# 95% CI: [-0.0050, 0.0550]
# Significance:
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 3 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'msch']
#
# PLR RESULTS:
# Coefficient: -0.0517
# Std Error: 0.0166
# P-value: 0.0018
# 95% CI: [-0.0842, -0.0192]
# Significance: ***
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 3 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'msch', 'dmy_mhtx']
#
# PLR RESULTS:
# Coefficient: -0.0005
# Std Error: 0.0117
# P-value: 0.9693
# 95% CI: [-0.0234, 0.0225]
# Significance:
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 4 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet']
#
# PLR RESULTS:
# Coefficient: -0.0740
# Std Error: 0.0182
# P-value: 0.0000
# 95% CI: [-0.1096, -0.0384]
# Significance: ***
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 4 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'dmy_mhtx']
#
# PLR RESULTS:
# Coefficient: -0.0155
# Std Error: 0.0134
# P-value: 0.2456
# 95% CI: [-0.0417, 0.0107]
# Significance:
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 5 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch']
#
# PLR RESULTS:
# Coefficient: -0.0516
# Std Error: 0.0145
# P-value: 0.0004
# 95% CI: [-0.0802, -0.0231]
# Significance: ***
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 5 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'dmy_mhtx']
#
# PLR RESULTS:
# Coefficient: -0.0124
# Std Error: 0.0116
# P-value: 0.2838
# 95% CI: [-0.0351, 0.0103]
# Significance:
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 6 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer']
#
# PLR RESULTS:
# Coefficient: -0.0345
# Std Error: 0.0148
# P-value: 0.0199
# 95% CI: [-0.0635, -0.0055]
# Significance: **
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 6 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer', 'dmy_mhtx']
#
# PLR RESULTS:
# Coefficient: -0.0148
# Std Error: 0.0121
# P-value: 0.2213
# 95% CI: [-0.0386, 0.0089]
# Significance:
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 7 (No Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer']
#
# PLR RESULTS:
# Coefficient: -0.0301
# Std Error: 0.0160
# P-value: 0.0604
# 95% CI: [-0.0616, 0.0013]
# Significance: *
#
# ==================================================
# ANALYSIS: Semi Skill Employment ~ Manufacturing High-Technology Exports
# SPECIFICATION: GMM Spec 7 (Country Dummies)
# ==================================================
# Data prepared: 924 obs, 0 dropped
# Controls used: ['fdi', 'gfcf', 'rnd', 'tariff', 'internet', 'msch', 'reer', 'dmy_mhtx']
#
# PLR RESULTS:
# Coefficient: -0.0055
# Std Error: 0.0136
# P-value: 0.6845
# 95% CI: [-0.0321, 0.0211]
# Significance:
#
#
# PLR ANALYSIS COMPLETED!
# Total successful analyses: 84

# %%
#9: Feature Importance Analysis

# Feature importance analysis for key models
print("=" * 80)
print("FEATURE IMPORTANCE ANALYSIS")
print("=" * 80)

def analyze_feature_importance(model, treatment_col, x_cols, model_type):
    """Extract and display feature importance"""

    if model.models is not None:
        try:
            if model_type == 'PLR':
                fitted_ml_l = model.models['ml_l'][treatment_col][0][0]
                fitted_ml_m = model.models['ml_m'][treatment_col][0][0]

                print(f"\n{model_type} FEATURE IMPORTANCE:")

                # Outcome model (ml_l)
                if hasattr(fitted_ml_l, 'feature_importances_'):
                    # Ensure correct feature names are used based on x_cols and treatment_col
                    outcome_features = x_cols + [treatment_col]
                    if len(fitted_ml_l.feature_importances_) == len(outcome_features):
                        importance_l = pd.Series(
                            fitted_ml_l.feature_importances_,
                            index=outcome_features
                        ).sort_values(ascending=False)

                        print(f"\nOutcome Model (Employment Prediction):")
                        for var, imp in importance_l.head(5).items():
                            print(f"  {var}: {imp:.4f}")

                # Treatment model (ml_m)
                if hasattr(fitted_ml_m, 'feature_importances_'):
                     if len(fitted_ml_m.feature_importances_) == len(x_cols):
                        importance_m = pd.Series(
                            fitted_ml_m.feature_importances_,
                            index=x_cols
                        ).sort_values(ascending=False)

                        print(f"\nTreatment Model (Export Quality Prediction):")
                        for var, imp in importance_m.head(5).items():
                            print(f"  {var}: {imp:.4f}")


        except Exception as e:
            print(f"Feature importance extraction failed: {e}")

# Analyze feature importance for selected models
selected_analyses = list(plr_results.keys())[:2]  # Analyze first 2 models

for key in selected_analyses:
    plr = plr_results[key]
    # irm = irm_results.get(key) # Removed IRM

    print(f"\n{'='*60}")
    print(f"FEATURE IMPORTANCE: {plr['dep_var']} ~ {plr['treat_var']}")
    print(f"SPECIFICATION: {MODEL_SPECS[plr['spec_id']]['name']}")
    print(f"{'='*60}")

    # PLR feature importance
    analyze_feature_importance(plr['model'], plr['treat_var'], plr['controls'], 'PLR')
# Out:
# ================================================================================
# FEATURE IMPORTANCE ANALYSIS
# ================================================================================
#
# ============================================================
# FEATURE IMPORTANCE: High Skill ~ uv_index
# SPECIFICATION: GMM Spec 1 (No Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Treatment Model (Export Quality Prediction):
#   mobile: 0.7235
#   tariff: 0.0911
#   msch: 0.0585
#   rnd: 0.0568
#   gfcf: 0.0369
#
# ============================================================
# FEATURE IMPORTANCE: High Skill ~ uv_index
# SPECIFICATION: GMM Spec 1 (Country Dummies)
# ============================================================
#
# PLR FEATURE IMPORTANCE:
#
# Treatment Model (Export Quality Prediction):
#   mobile: 0.5523
#   dmy_uvindex: 0.3273
#   reer: 0.0515
#   gfcf: 0.0356
#   rnd: 0.0207

# %%
#10: Economic Interpretation and Policy Implications

# Economic interpretation and policy implications
print("=" * 80)
print("ECONOMIC INTERPRETATION AND POLICY IMPLICATIONS")
print("=" * 80)

def interpret_results(coef, treat_var, method):
    """Provide economic interpretation of results"""

    if treat_var == 'EQI_IMF':
        treatment_name = "Export Quality Indicator (IMF)"
        unit = "unit increase"
    elif treat_var == 'uv_index':
        treatment_name = "export unit value (quality)"
        unit = "unit increase in quality index"
    elif treat_var == 'mhtx':
        treatment_name = "Manufacturing High-Technology Exports"
        unit = "unit increase"


    effect_direction = "increases" if coef > 0 else "decreases"
    effect_magnitude = "large" if abs(coef) > 0.1 else "moderate" if abs(coef) > 0.05 else "small"

    interpretation = f"""
    A 1-{unit} in {treatment_name} {effect_direction} employment by {abs(coef):.4f} percentage points.
    This represents a {effect_magnitude} {effect_direction[:-1]}ing effect estimated using {method}.
    """

    return interpretation.strip()

# Interpret key results
print("\nKEY FINDINGS:")
print("-" * 40)

for i, (key, plr) in enumerate(plr_results.items()):
    if i >= 3:  # Limit to first 3 results
        break

    # irm = irm_results.get(key) # Removed IRM

    dep_desc = DEPENDENT_VARS[plr['dep_var']]
    treat_desc = TREATMENT_VARS[plr['treat_var']]
    spec_name = MODEL_SPECS[plr['spec_id']]['name']

    print(f"\n{i+1}. {dep_desc} and {treat_desc} ({spec_name})")
    print("   " + "="*50)

    # PLR interpretation
    print(f"   PLR Result: {interpret_results(plr['coef'], plr['treat_var'], 'PLR')}")

    # IRM interpretation if available - Removed
    # if irm:
    #     print(f"   IRM Result: {interpret_results(irm['coef'], irm['treat_var'], 'IRM')}")

    #     # Compare methods
    #     if abs(plr['coef'] - irm['coef']) / abs(plr['coef']) > 0.1:
    #         print(f"   → HETEROGENEITY: Significant differences suggest country-specific effects")
    #     else:
    #         print(f"   → CONSISTENCY: PLR and IRM estimates are similar")

print(f"\n\nPOLICY IMPLICATIONS:")
print("-" * 30)
print("1. Export Quality Upgrading:")
print("   - Positive coefficients suggest export quality improvements boost employment")
print("   - Effect sizes indicate magnitude of policy impact")

print("\n2. Technology Export Promotion:")
print("   - MHTX coefficients show employment effects of high-tech export policies")
print("   - Consider heterogeneous effects across countries (IRM insights)") # This line needs to be updated as IRM is removed

print("\n3. Targeted Interventions:") # This section needs to be updated as IRM is removed
print("   - IRM results reveal which countries benefit most from quality upgrading")
print("   - PLR provides average effects for broad policy recommendations")

print("\n4. Robustness:")
print("   - Compare with GMM and Driscoll-Kraay results for validation")
print("   - Multiple specifications ensure result stability")
# Out:
# ================================================================================
# ECONOMIC INTERPRETATION AND POLICY IMPLICATIONS
# ================================================================================
#
# KEY FINDINGS:
# ----------------------------------------
#
# 1. High Skill Employment and Export Unit Value Index (Quality) (GMM Spec 1 (No Dummies))
#    ==================================================
#    PLR Result: A 1-unit increase in quality index in export unit value (quality) decreases employment by 0.0272 percentage points.
#     This represents a small decreaseing effect estimated using PLR.
#
# 2. High Skill Employment and Export Unit Value Index (Quality) (GMM Spec 1 (Country Dummies))
#    ==================================================
#    PLR Result: A 1-unit increase in quality index in export unit value (quality) decreases employment by 0.0366 percentage points.
#     This represents a small decreaseing effect estimated using PLR.
#
# 3. High Skill Employment and Export Unit Value Index (Quality) (GMM Spec 2 (No Dummies))
#    ==================================================
#    PLR Result: A 1-unit increase in quality index in export unit value (quality) decreases employment by 0.0170 percentage points.
#     This represents a small decreaseing effect estimated using PLR.
#
#
# POLICY IMPLICATIONS:
# ------------------------------
# 1. Export Quality Upgrading:
#    - Positive coefficients suggest export quality improvements boost employment
#    - Effect sizes indicate magnitude of policy impact
#
# 2. Technology Export Promotion:
#    - MHTX coefficients show employment effects of high-tech export policies
#    - Consider heterogeneous effects across countries (IRM insights)
#
# 3. Targeted Interventions:
#    - IRM results reveal which countries benefit most from quality upgrading
#    - PLR provides average effects for broad policy recommendations
#
# 4. Robustness:
#    - Compare with GMM and Driscoll-Kraay results for validation
#    - Multiple specifications ensure result stability
